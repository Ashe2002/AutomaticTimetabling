# %% [markdown]
# ### 0: Downloading Programmes

# %%
import gurobipy as gp
from gurobipy import GRB
import pyomo.environ as pyo
from pyomo.opt import SolverFactory
import pandas as pd
from pathlib import Path
from collections import defaultdict

# %% [markdown]
# ### 1: Dataframes

# %%
base = Path("output_folder")

df_resources = pd.read_csv(base / "resources.csv") # resource ID and resource type
df_constraints = pd.read_csv(base / "constraints.csv") # constraint ID and type, Name, required?, weight and cost function

df_times = pd.read_csv(base / "times.csv").sort_values("order_index") # timeslots and their timegroups (days)


# df_events = event with its duration, course, groups, role, classes and teacher)

events = pd.read_csv(base / "events.csv") 
event_groups = pd.read_csv(base / "event_eventgroup_membership.csv")
event_resources = pd.read_csv(base / "event_resources.csv")

# Events each group is part of
groups_per_event = (
    event_groups
    .groupby("event_id")["event_group_id"]
    .apply(list)
    .reset_index(name="groups")
)

# Teacher of each event
teachers_per_event = event_resources[event_resources["role"].isna()]
teachers_per_event = ( teachers_per_event[["event_id", "reference_resource_id"]]
    .groupby("event_id")["reference_resource_id"]
    .apply(list)
    .reset_index(name="teachers")
) 

#Classes in each event
classes_per_event = event_resources[event_resources["role"].astype(str).str.startswith("Class")]
classes_per_event = ( classes_per_event[["event_id", "reference_resource_id"]]
    .groupby("event_id")["reference_resource_id"]
    .apply(list)
    .reset_index(name="classes")
)

# Role of each event
role_per_event = event_resources[event_resources["resource_type_ref"] == "Room"]
role_per_event = (role_per_event[["event_id", "role"]]
    .groupby("event_id")["role"]
    .first()
    .reset_index(name="role")
)


# Room of each event
room_per_event = event_resources[event_resources["role"] == "Room"]
room_per_event = (room_per_event[["event_id", "reference_resource_id"]]
    .groupby("event_id")["reference_resource_id"]
    .apply(list)
    .reset_index(name="room")
)

# Students of each event
students_per_event = event_resources[event_resources["role"] == "Student"]
students_per_event = (students_per_event[["event_id", "reference_resource_id"]]
    .groupby("event_id")["reference_resource_id"]
    .apply(list)
    .reset_index(name="students")
)

df_events = (
    events.rename(columns={"course_ref": "course_reference"})[["event_id", "duration", "course_reference"]]
    .merge(groups_per_event, on="event_id", how="left")
    .merge(role_per_event, on="event_id", how="left")
    .merge(room_per_event, on="event_id", how="left")
    .merge(classes_per_event, on="event_id", how="left")
    .merge(teachers_per_event, on="event_id", how="left")
    .merge(students_per_event, on="event_id", how="left")
) # event with its duration, course, groups, role, classes and teacher)



resource_groups = pd.read_csv(base / "resource_group_membership.csv")

# Keep only what we need from memberships and aggregate group memberships
groups_per_resource = (
    resource_groups
    .groupby("resource_id")["resource_group_id"]
    .apply(list)
    .reset_index(name="resource_groups")
)

# Merge onto resources
df_res_with_groups = (
    df_resources[["resource_id", "resource_type_ref"]]
    .merge(groups_per_resource, on="resource_id", how="left")
)

# Replace NaN with empty list (resources that have no group membership)
df_res_with_groups["resource_groups"] = df_res_with_groups["resource_groups"].apply(
    lambda x: x if isinstance(x, list) else []
)


# Split into separate tables
df_teachers = df_res_with_groups[df_res_with_groups["resource_type_ref"] == "Teacher"].reset_index(drop=True) # teacher id, resource type and list of groups
df_classes  = df_res_with_groups[df_res_with_groups["resource_type_ref"] == "Class"].reset_index(drop=True) # class id, resource type and list of groups
df_rooms    = df_res_with_groups[df_res_with_groups["resource_type_ref"] == "Room"].reset_index(drop=True) # room id, resource type and list of groups
df_students = df_res_with_groups[df_res_with_groups["resource_type_ref"] == "Student"].reset_index(drop=True) # room id, resource type and list of groups


df_res_long = (
    df_resources[["resource_id", "resource_type_ref"]]
    .merge(resource_groups[["resource_id", "resource_group_id"]], on="resource_id", how="left")
    .rename(columns={"resource_group_id": "resource_group"})
)
df_teachers_long = df_res_long[df_res_long["resource_type_ref"] == "Teacher"] # teacher id, resource type and seperate groups
df_classes_long  = df_res_long[df_res_long["resource_type_ref"] == "Class"] # class id, resource type and seperate groups
df_rooms_long    = df_res_long[df_res_long["resource_type_ref"] == "Room"] # room id, resource type and seperate groups
df_students_long = df_res_long[df_res_long["resource_type_ref"] == "Student"].reset_index(drop=True) # room id, resource type and list of groups



df_constraint_applied = pd.read_csv(base / "constraint_applies_to.csv")
df_constraint_params = pd.read_csv(base / "constraint_params.csv")

df_constraint_params = df_constraint_params.merge(
    df_constraints[["constraint_id", "constraint_type"]],
    on="constraint_id",
    how="left"
)

df_constraint_params = df_constraint_params.merge(
    df_constraint_applied[["constraint_id", "reference"]],
    on="constraint_id",
    how="left"
)

# %%
#print(df_resources)
#print(df_constraints)

#print(df_times)
#print(df_events)
#print(df_rooms)
#print(df_teachers)
#print(df_classes)
#df_students

#df_constraint_params

# %%
# Core tables
events = pd.read_csv(base / "events.csv")[["event_id", "duration"]].copy()
events["duration"] = events["duration"].astype(int)

constraints = pd.read_csv(base / "constraints.csv")
constraint_params = pd.read_csv(base / "constraint_params.csv")
constraint_applied = pd.read_csv(base / "constraint_applies_to.csv")

# 1) Keep only split constraints
split_cons = constraints.loc[
    constraints["constraint_type"].eq("SplitEventsConstraint"),
    ["constraint_id", "required", "weight", "cost_function"]
].copy()

# 2) Extract split parameters (min/max duration + amount)
needed_paths = {
    "MinimumDuration": "min_duration",
    "MaximumDuration": "max_duration",
    "MinimumAmount": "min_amount",
    "MaximumAmount": "max_amount",
}

split_params = (
    constraint_params[constraint_params["constraint_id"].isin(split_cons["constraint_id"])]
    .loc[lambda d: d["path"].isin(needed_paths.keys()), ["constraint_id", "path", "value"]]
    .assign(path=lambda d: d["path"].map(needed_paths), value=lambda d: d["value"].astype(int))
    .pivot_table(index="constraint_id", columns="path", values="value", aggfunc="first")
    .reset_index()
)

split_specs = split_cons.merge(split_params, on="constraint_id", how="left")

# 3) Which events each split constraint applies to
split_applied = (
    constraint_applied[
        (constraint_applied["constraint_id"].isin(split_specs["constraint_id"]))
        & (constraint_applied["path"] == "AppliesTo/Events/Event")
    ][["constraint_id", "reference"]]
    .rename(columns={"reference": "event_id"})
)

# 4) Event + split spec rows
event_split = (
    split_applied
    .merge(events, on="event_id", how="left")
    .merge(split_specs, on="constraint_id", how="left")
)

# Guard: each event should be controlled by at most one split constraint
dup_events = event_split["event_id"][event_split["event_id"].duplicated()].unique().tolist()
if dup_events:
    raise ValueError(f"Events with multiple split constraints: {dup_events[:10]} ...")

def choose_split_durations(total_d, min_amt, max_amt, min_dur, max_dur):
    """
    Find integer sub-event durations s.t.
      n in [min_amt, max_amt]
      each dur in [min_dur, max_dur]
      sum(durs) = total_d
    Returns list of durations or None if impossible.
    """
    for n in range(min_amt, max_amt + 1):
        if n * min_dur <= total_d <= n * max_dur:
            base = total_d // n
            rem = total_d % n
            durs = [base + 1] * rem + [base] * (n - rem)
            if all(min_dur <= x <= max_dur for x in durs):
                return durs
    return None

rows = []
errors = []

# 5) Build sub-events for constrained events
for r in event_split.itertuples(index=False):
    durs = choose_split_durations(
        total_d=int(r.duration),
        min_amt=int(r.min_amount),
        max_amt=int(r.max_amount),
        min_dur=int(r.min_duration),
        max_dur=int(r.max_duration),
    )

    if durs is None:
        if str(r.required).upper() == "TRUE":
            errors.append(
                {
                    "event_id": r.event_id,
                    "constraint_id": r.constraint_id,
                    "duration": int(r.duration),
                    "min_amount": int(r.min_amount),
                    "max_amount": int(r.max_amount),
                    "min_duration": int(r.min_duration),
                    "max_duration": int(r.max_duration),
                }
            )
            continue
        else:
            durs = [int(r.duration)]  # soft violation fallback

    for k, sd in enumerate(durs, start=1):
        rows.append(
            {
                "parent_event_id": r.event_id,
                "sub_event_id": f"{r.event_id}__sub{k}",
                "sub_index": k,
                "sub_duration": int(sd),
                "split_constraint_id": r.constraint_id,
                "required": r.required,
                "weight": r.weight,
                "cost_function": r.cost_function,
                "was_split": len(durs) > 1,
            }
        )

# 6) Add unconstrained events as single sub-events
constrained_events = set(event_split["event_id"].tolist())
for r in events.itertuples(index=False):
    if r.event_id in constrained_events:
        continue
    rows.append(
        {
            "parent_event_id": r.event_id,
            "sub_event_id": f"{r.event_id}__sub1",
            "sub_index": 1,
            "sub_duration": int(r.duration),
            "split_constraint_id": None,
            "required": None,
            "weight": None,
            "cost_function": None,
            "was_split": False,
        }
    )

sub_events = pd.DataFrame(rows).sort_values(["parent_event_id", "sub_index"]).reset_index(drop=True)

if errors:
    df_split_errors = pd.DataFrame(errors)
    print("Required split constraints with no feasible split found:")
    print(df_split_errors.head(20))
else:
    df_split_errors = pd.DataFrame()
    print("All required split constraints produced feasible sub-events.")

print(f"Parents: {events['event_id'].nunique()}, Sub-events: {sub_events['sub_event_id'].nunique()}")
# Out:
# All required split constraints produced feasible sub-events.
# Parents: 628, Sub-events: 2849

# %%
# Keep only needed split columns
sub_core = sub_events[
    ["parent_event_id", "sub_event_id", "sub_duration"]
].copy()

# Parent event attributes to carry down to each sub-event
parent_attrs = df_events[
    ["event_id", "course_reference", "groups", "room", "classes", "teachers", "students"]
].rename(columns={"event_id": "parent_event_id"})

# Final sub-event dataframe
df_sub_events = (
    sub_core
    .merge(parent_attrs, on="parent_event_id", how="left")
    .sort_values(["parent_event_id", "sub_event_id"])
    .reset_index(drop=True)
)

# optional check
missing = df_sub_events["course_reference"].isna().sum()
print(f"df_sub_event rows: {len(df_sub_events)}, missing parent attrs: {missing}")
# Out:
# df_sub_event rows: 2849, missing parent attrs: 2849

# %%
df_sub_events
# Out:
#                  parent_event_id                      sub_event_id  \
# 0     Accounting-Advanced(H)_0_1  Accounting-Advanced(H)_0_1__sub1
# 1     Accounting-Advanced(H)_0_1  Accounting-Advanced(H)_0_1__sub2
# 2     Accounting-Advanced(H)_0_1  Accounting-Advanced(H)_0_1__sub3
# 3     Accounting-Advanced(H)_0_1  Accounting-Advanced(H)_0_1__sub4
# 4        Accounting-Begining_0_1     Accounting-Begining_0_1__sub1
# ...                          ...                               ...
# 2844                 german3_0_1                 german3_0_1__sub4
# 2845                 german3_0_1                 german3_0_1__sub5
# 2846                 german3_0_1                 german3_0_1__sub6
# 2847                 german3_0_1                 german3_0_1__sub7
# 2848                 german3_0_1                 german3_0_1__sub8
#
#       sub_duration  course_reference                                   groups  \
# 0                2               NaN  [Event_All, Accounting-Advanced(H)_0_1]
# 1                2               NaN  [Event_All, Accounting-Advanced(H)_0_1]
# 2                2               NaN  [Event_All, Accounting-Advanced(H)_0_1]
# 3                2               NaN  [Event_All, Accounting-Advanced(H)_0_1]
# 4                2               NaN     [Event_All, Accounting-Begining_0_1]
# ...            ...               ...                                      ...
# 2844             2               NaN                 [Event_All, german3_0_1]
# 2845             2               NaN                 [Event_All, german3_0_1]
# 2846             2               NaN                 [Event_All, german3_0_1]
# 2847             2               NaN                 [Event_All, german3_0_1]
# 2848             2               NaN                 [Event_All, german3_0_1]
#
#      room classes       teachers students
# 0     NaN     NaN  [Teacher_180]      NaN
# 1     NaN     NaN  [Teacher_180]      NaN
# 2     NaN     NaN  [Teacher_180]      NaN
# 3     NaN     NaN  [Teacher_180]      NaN
# 4     NaN     NaN   [Teacher_36]      NaN
# ...   ...     ...            ...      ...
# 2844  NaN     NaN   [Teacher_74]      NaN
# 2845  NaN     NaN   [Teacher_74]      NaN
# 2846  NaN     NaN   [Teacher_74]      NaN
# 2847  NaN     NaN   [Teacher_74]      NaN
# 2848  NaN     NaN   [Teacher_74]      NaN
#
# [2849 rows x 9 columns]

# %% [markdown]
# ### 2: Model setup and helpers

# %%
def as_list(x):
    if x is None:
        return []
    if isinstance(x, (list, tuple, set)):
        return list(x)
    return [x]

# %%
### Sets

E = df_events["event_id"].tolist() # All events
T = df_times["time_id"].tolist() # All timeslots
R = df_rooms["resource_id"].tolist() # All rooms

all_teachers = df_teachers["resource_id"].tolist()
all_classes = df_classes["resource_id"].tolist()
all_students = df_students["resource_id"].tolist()

SE = df_sub_events["sub_event_id"].tolist()



# sub_event -> duration/teachers/classes (lists)
subevent_to_duration = dict(zip(df_sub_events["sub_event_id"], df_sub_events["sub_duration"].astype(int))) # duration of each event
subevent_to_teachers = dict(zip(df_sub_events["sub_event_id"], df_sub_events["teachers"])) # teachers for each event
#event_to_classes  = dict(zip(df_events["event_id"], df_events["classes"])) # classes for each event
subevent_to_room = dict(zip(df_sub_events["sub_event_id"], df_sub_events["room"])) # Room for each event
#subevent_to_students  = dict(zip(df_events["event_id"], df_events["students"])) # students for each event


# event -> room group of each event
#event_to_roomgroup = dict(zip(df_events["event_id"], df_events["role"])) 

room_to_group = (
    df_rooms_long[["resource_id", "resource_group"]]
    .dropna(subset=["resource_group"])
    .drop_duplicates()
    .groupby("resource_id")["resource_group"]
    .apply(list)
    .to_dict()
)

group_to_room = (
    df_rooms_long[["resource_id", "resource_group"]]
    .dropna(subset=["resource_group"])
    .drop_duplicates()
    .groupby("resource_group")["resource_id"]
    .apply(list)
    .to_dict()
)


T_index = {t:i for i,t in enumerate(T)}

# Keep only true unavailability constraints (exclude "NotPreferred")
df_unavail_times = df_constraint_params[
    (df_constraint_params["constraint_type"] == "AvoidUnavailableTimesConstraint") &
    (df_constraint_params["path"] == "Times/Time") &
    (~df_constraint_params["constraint_id"].astype(str).str.contains("NotPreferred", case=False, na=False))
].copy()[["reference", "value"]]

# resource -> set(unavailable times)
resource_unavailability = (
    df_unavail_times
    .groupby("reference")["value"]
    .agg(lambda s: set(s))
    .to_dict()
)

# %%
df_constraint_params
# Out:
#       instance_id           constraint_id          path  attr        value  \
# 0        US-WS-09             AssignRooms          Name  text  AssignRooms
# 1        US-WS-09             AssignRooms      Required  text         TRUE
# 2        US-WS-09             AssignRooms        Weight  text            1
# 3        US-WS-09             AssignRooms  CostFunction  text       Linear
# 4        US-WS-09             AssignRooms          Role  text            1
# ...           ...                     ...           ...   ...          ...
# 49912    US-WS-09  AvoidClashesConstraint      Required  text         TRUE
# 49913    US-WS-09  AvoidClashesConstraint        Weight  text            1
# 49914    US-WS-09  AvoidClashesConstraint        Weight  text            1
# 49915    US-WS-09  AvoidClashesConstraint  CostFunction  text       Linear
# 49916    US-WS-09  AvoidClashesConstraint  CostFunction  text       Linear
#
#                 constraint_type    reference
# 0      AssignResourceConstraint    Event_All
# 1      AssignResourceConstraint    Event_All
# 2      AssignResourceConstraint    Event_All
# 3      AssignResourceConstraint    Event_All
# 4      AssignResourceConstraint    Event_All
# ...                         ...          ...
# 49912    AvoidClashesConstraint  Teacher_All
# 49913    AvoidClashesConstraint     Room_All
# 49914    AvoidClashesConstraint  Teacher_All
# 49915    AvoidClashesConstraint     Room_All
# 49916    AvoidClashesConstraint  Teacher_All
#
# [49917 rows x 7 columns]

# %%
### Feasible Start times for events:

#T_index = {t:i for i,t in enumerate(T)}

time_to_day = dict(zip(df_times["time_id"], df_times["day_ref"]))

# Build feasible starts per event (no crossing day boundary) (implicitely covers constraints 5,9,10,11,12)
feasible_starts = {}
for se in SE:
    d = int(subevent_to_duration[se]) # number of periods needed
    starts = []
    for ts in T: # for all possible start times
        i0 = T_index[ts]
        # must have enough periods remaining in the global list
        if i0 + d - 1 >= len(T):
            continue
        day0 = time_to_day[ts]
        block = T[i0:i0 + d]
        # enforce all times in the block are same day
        if all(time_to_day[t] == day0 for t in block):
            starts.append(ts)
    feasible_starts[se] = starts

# If event e starts at ts, then occ_times[(e, ts)] = [t1, t2, ...] is the list of all times occupied by that event
occ_times = {}
for se in SE:
    d = int(subevent_to_duration[se])
    for ts in feasible_starts[se]:
        i0 = T_index[ts]
        occ_times[(se, ts)] = T[i0:i0 + d]


# Helper: all (e, ts) pairs that occupy a given time t
# ie for Fr_3, if event 1 is duration 1 and event 2 is duration 2, then (1, Fr_3) and (2, Fr_2) and (2, Fr_3) occupy it
occupies_at_time = {t: [] for t in T}
for se in SE:
    for ts in feasible_starts[se]:
        for t in occ_times[(se, ts)]:
            occupies_at_time[t].append((se, ts))

# %%
feasible_rooms = {se: list(R) for se in SE}

# %% [markdown]
# ### 2b: Pyomo Model part 1: Sets and Decision Variables

# %% [markdown]
# Constraints:
#
# Part 1: Event -> Time (hard constraints only)
# 1) AssignTimes: [gr_EventsGeneral] Every event must be assigned a time
# 2) NoResourceClashes: No clashes for any of the resources
# 3) SplitEventsCOnstraint_number: Events from selected event group should be split between a min and max number of subevents, with each subevent being between a min and max number of time periods
# 4) SameDay_Duration(2/3/4): Events of duration 2,3 and 4 must start at valid times (no bleeding into the next day)
#
# Extra: Number of events at any one time should be less than number of rooms available
#
# Part 2: Event -> Time (with soft constraints)
# 1) PreferTimesConstraint(waffle): sub-events of selected event and of given duration have preffered times in which they are scheduled (start times) (soft: weight = 4, linear)
# 2) SpreadEventsConstraint_course: between a min and max (day group specific) number of sub-events of selected event can occur on a given day (soft: weight=1, linear)
#
# Part 3: Event -> Room
# 1) Every event must be assigned exactly 1 room
# 2) At most one event can occupy a room at a time
# 3) PreferResourcesConstraint_Room: Selected event prefers to be scheduled with selected room or room (soft: weight=1, linear)
# 4) PreferResourcesConstraint_Dept: Selected event prefers to be scheduled with selected room group room (soft: weight=1, linear)

# %% [markdown]
# ### MODEL

# %%
from collections import defaultdict
import pyomo.environ as pyo

# ---- Model ----
m1 = pyo.ConcreteModel()

# ---- Sets ----
m1.E = pyo.Set(initialize=E)
m1.T = pyo.Set(initialize=T, ordered=True)
m1.R = pyo.Set(initialize=R)

m1.Teachers = pyo.Set(initialize=all_teachers)
m1.Classes = pyo.Set(initialize=all_classes)
m1.Students = pyo.Set(initialize=all_students)

m1.SE = pyo.Set(initialize=SE)


def x_index_init(m):
    for se in SE:
        for ts in feasible_starts[se]:
            for r in feasible_rooms[se]:
                yield (se, ts, r)

m1.X_index = pyo.Set(dimen=3, initialize=x_index_init)


# Map occupied times to feasible triples
occupies_at_time = defaultdict(list)
occupies_at_time_room = defaultdict(list)

for (se, ts, r) in m1.X_index:
    for t in occ_times[(se, ts)]:
        occupies_at_time[t].append((se, ts, r))
        occupies_at_time_room[(t, r)].append((se, ts, r))

# ---- Decision Variables ----
# x[se, ts, r] = 1 if sub-event se starts at time ts in room r
m1.x = pyo.Var(m1.X_index, domain=pyo.Binary)

# %%
from ipykernel import get_connection_file
print(get_connection_file())
# Out:
# c:\Users\asher\AppData\Roaming\jupyter\runtime\kernel-v313ee48afb499d3f730b4a0e31211281f91750a3c.json

# %%
# Hard

# 1) Each sub-event scheduled exactly once
def one_start_room_rule(m, se):
    return sum(
        m.x[se, ts, r]
        for ts in feasible_starts[se]
        for r in feasible_rooms[se]
        if (se, ts, r) in m.X_index
    ) == 1

m1.OneStartRoom = pyo.Constraint(m1.SE, rule=one_start_room_rule)

# %%
# 2) No room conflicts: at most one sub-event can occupy a room at a time
def room_conflict_rule(m, r, t):
    terms = [
        m.x[se, ts, r]
        for (se, ts, r) in occupies_at_time_room.get((t, r), [])
    ]
    if not terms:
        return pyo.Constraint.Skip
    return sum(terms) <= 1

m1.RoomConflict = pyo.Constraint(m1.R, m1.T, rule=room_conflict_rule)

# %%
# 3) No teacher conflicts: a teacher can teach at most one sub-event at a time
def teacher_conflict_rule(m, teacher, t):
    terms = [
        m.x[se, ts, r]
        for (se, ts, r) in occupies_at_time.get(t, [])
        if teacher in as_list(subevent_to_teachers[se])
    ]
    if not terms:
        return pyo.Constraint.Skip
    return sum(terms) <= 1

m1.TeacherConflict = pyo.Constraint(m1.Teachers, m1.T, rule=teacher_conflict_rule)

# %% [markdown]
# ### 2b: Model 1

# %%
# ---- Model ----
m1 = pyo.ConcreteModel()

# ---- Sets ----
m1.E = pyo.Set(initialize=E) # Set of events
m1.T = pyo.Set(initialize=T, ordered=True) # Set of timeslots (ordered)
m1.R = pyo.Set(initialize=R) # Set of rooms

m1.Teachers = pyo.Set(initialize=all_teachers) # set of all teachers
m1.Classes = pyo.Set(initialize=all_classes) # set of all classes
m1.Students = pyo.Set(initialize=all_students)

m1.SE = pyo.Set(initialize=SE) # Set of events
# standard set up
m1.X_index = pyo.Set(
    dimen=2,
    initialize=[(se, ts) for se in SE for ts in feasible_starts[se]]
)



# ---- Decision Variables ----
# Start-time decision variables:
# x[e, ts, r] = 1 if event e starts at time ts in room r
# Only define variables for feasible starts (and all rooms) (THIS SPEEDS UP MODEL)
m1.x = pyo.Var(m1.X_index, domain=pyo.Binary)

# %%
# Standard set up

# 1) Each event scheduled exactly once (one start time)   (covers constraints 4)
def one_start_rule(m, se):
    return sum(m.x[se, ts] for ts in feasible_starts[se]) == 1
m1.OneStart = pyo.Constraint(m1.SE, rule=one_start_rule)


# 3) No teacher conflicts: a teacher can teach at most one event at a time
def teacher_conflict_rule(m, teacher, t):
    terms = [
        m.x[se, ts]
        for (se, ts) in occupies_at_time.get(t, [])
        if teacher in as_list(subevent_to_teachers[se])
    ]
    if not terms:
        return pyo.Constraint.Skip   # or pyo.Constraint.Feasible
    return sum(terms) <= 1

m1.TeacherConflict = pyo.Constraint(all_teachers, m1.T, rule=teacher_conflict_rule)


#m1.ClassConflict = pyo.Constraint(all_classes, m1.T, rule=class_conflict_rule)


#m1.StudentConflict = pyo.Constraint(all_students, m1.T, rule=student_conflict_rule)


# 5) Max number of simultaneous events cannot exceed number of rooms
m1.N_rooms = pyo.Param(initialize=len(R), within=pyo.NonNegativeIntegers)

def total_events_vs_rooms_rule(m, t):
    terms = [m.x[se, ts] for (se, ts) in occupies_at_time.get(t, [])]
    if not terms:
        return pyo.Constraint.Skip
    return sum(terms) <= m.N_rooms

m1.TotalEventsVsRooms = pyo.Constraint(m1.T, rule=total_events_vs_rooms_rule)

# %% [markdown]
# ### Solve

# %%
# ---- Objective ---- (hard constraints only)
m1.obj = pyo.Objective(expr=0, sense=pyo.minimize)

# %%
# ---- Solve ---

solver = pyo.SolverFactory("gurobi")
solver.options["TimeLimit"] = 1000
# solver.options["MIPGap"] = 0.0

res = solver.solve(m1, tee=True)

print(res.solver.termination_condition)
# Out:
# Read LP format model from file C:\Users\asher\AppData\Local\Temp\tmphhwqt0ss.pyomo.lp
# Reading time = 1.19 seconds
# x1: 16349 rows, 267376 columns, 1448435 nonzeros
# Set parameter TimeLimit to value 1000
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: Intel(R) Core(TM) i5-10210U CPU @ 1.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  1000
#
# Optimize a model with 16349 rows, 267376 columns and 1448435 nonzeros (Min)
# Model fingerprint: 0x36d6ad39
# Model has 0 linear objective coefficients
# Variable types: 1 continuous, 267375 integer (267375 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
# Found heuristic solution: objective 0.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.11 seconds (0.03 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
# optimal

# %%
start_x = {}
for idx in m1.X_index:
    v = pyo.value(m1.x[idx], exception=False)
    start_x[idx] = 0.0 if v is None else float(v)

#start_x

# %% [markdown]
# ### 2c: Model 2

# %%
df_time_group_membership = pd.read_csv(base / "time_group_membership.csv")

# ---- keep prefer-time constraints ----
cdf = df_constraints[df_constraints["constraint_type"] == "PreferTimesConstraint"].copy()
cdf = cdf[cdf["required"].astype(str).str.upper() != "TRUE"]
cids = set(cdf["constraint_id"])

# ---- helper maps ----
cid_to_weight = cdf.set_index("constraint_id")["weight"].astype(float).to_dict()

# preferred times from explicit Times/Time
pref_times = {cid: set() for cid in cids} # map constraint -> preferred times

# df each row a constraint and a preferred time
t_rows = df_constraint_params[  
    (df_constraint_params["constraint_id"].isin(cids)) &
    (df_constraint_params["path"] == "Times/Time")
][["constraint_id", "value"]]
for r in t_rows.itertuples(index=False):
    pref_times[r.constraint_id].add(r.value)
pref_times

# preferred times from TimeGroups/TimeGroup -> expand via time_group_membership
tg_rows = df_constraint_params[ ### idrk about this one
    (df_constraint_params["constraint_id"].isin(cids)) &
    (df_constraint_params["path"] == "TimeGroups/TimeGroup")
][["constraint_id", "value"]]

# Map Time group -> times
tg_to_times = (
    df_time_group_membership.groupby("group_id")["time_id"].apply(set).to_dict()
)
for r in tg_rows.itertuples(index=False):
    pref_times[r.constraint_id].update(tg_to_times.get(r.value, set()))
tg_to_times
pref_times

# applies-to events (direct event refs)
applied_event = (
    df_constraint_applied[
        (df_constraint_applied["constraint_id"].isin(cids)) &
        (df_constraint_applied["path"] == "AppliesTo/Events/Event")
    ][["constraint_id", "reference"]]
    .groupby("constraint_id")["reference"].apply(set).to_dict()
)
applied_event

 # applies-to event groups -> expand to events
applies_eg = df_constraint_applied[
    (df_constraint_applied["constraint_id"].isin(cids)) &
    (df_constraint_applied["path"] == "AppliesTo/EventGroups/EventGroup")
][["constraint_id", "reference"]]

df_event_groups_membership = pd.read_csv(base / "event_eventgroup_membership.csv")

eg_to_events = (
    df_event_groups_membership.groupby("event_group_id")["event_id"].apply(set).to_dict()
)

# map constraint -> events applied to
applied_events = {cid: set(applied_event.get(cid, set())) for cid in cids}
for r in applies_eg.itertuples(index=False):
    applied_events[r.constraint_id].update(eg_to_events.get(r.reference, set()))
applied_events


# parent event -> sub-events / durations
parent_to_sub = df_sub_event.groupby("parent_event_id")["sub_event_id"].apply(list).to_dict()
sub_duration = df_sub_event.set_index("sub_event_id")["sub_duration"].astype(int).to_dict()

# %%
def add_prefer_times_penalty(model, x):
    """
    Assumes these are already defined in outer scope:
      cids, cid_to_weight, pref_times, dur_filter,
      applies_events, parent_to_sub, sub_duration, feasible_starts_sub
    """
    penalty = 0.0

    for cid in cids:  # loop over each prefer-times constraint
        w = 4 # constraints weight
        pref = pref_times.get(cid, set()) # preferred starttimes for this constraint
        

        for parent_event in applies_events.get(cid, set()): # loop over parent events constraint applies to
            for se in parent_to_sub.get(parent_event, []): # loop through sub events of parent event
                d_se = int(sub_duration[se]) # sub event duration
                starts = feasible_starts.get(se, []) # sub event feasible start times
                if not starts:
                    continue # unassigned handled elsewhere

                # strict XHSTT interpretation: start-time membership only
                bad_start = sum((0 if ts in pref else 1) * x[se, ts] for ts in starts)  # =1 if chosen start is not preferred
                dev_se = d_se * bad_start #deviation = sub event duration 

                penalty += w * dev_se

    model.PreferredTimesPenalty = pyo.Expression(expr=penalty)
    return model.pref_times_penalty

# %%
add_prefer_times_penalty(m1,m1.x)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[253], line 1
# ----> 1 add_prefer_times_penalty(m1,m1.x)
#
# Cell In[252], line 28, in add_prefer_times_penalty(model, x)
#      25             penalty += w * dev_se
#      27 model.PreferredTimesPenalty = pyo.Expression(expr=penalty)
# ---> 28 return model.pref_times_penalty
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pyomo\core\base\block.py:552, in BlockData.__getattr__(self, val)
#     549     return _component_decorator(self, ModelComponentFactory.get_class(val))
#     550 # Since the base classes don't support getattr, we can just
#     551 # throw the "normal" AttributeError
# --> 552 raise AttributeError(
#     553     "'%s' object has no attribute '%s'" % (self.__class__.__name__, val)
#     554 )
#
# AttributeError: 'ConcreteModel' object has no attribute 'pref_times_penalty'

# %%
# 1) pick spread constraints
cdf = df_constraints[df_constraints["constraint_type"] == "SpreadEventsConstraint"].copy()
cdf = cdf[cdf["required"].astype(str).str.upper() != "TRUE"] # dataframe of spreadevents constraints

spread_cids = set(cdf["constraint_id"]) #constraint IDs
cid_to_weight = cdf.set_index("constraint_id")["weight"].astype(float).to_dict() # weight of each constraint

# 2) time_group -> set(times)
tg_to_times = (
    df_time_group_membership.groupby("group_id")["time_id"].apply(set).to_dict()
)

# 3) parse per-constraint TimeGroups/TimeGroup + Minimum + Maximum
    #    (flattened CSV needs ordered scan)
cp = df_constraint_params[df_constraint_params["constraint_id"].isin(spread_cids)].copy()
cp = cp.reset_index(drop=False).rename(columns={"index": "_row_order"})
cp = cp.sort_values(["constraint_id", "_row_order"])

cid_to_tg_bounds = {}  # cid -> list[(time_group_id, min, max)]
for cid, g in cp.groupby("constraint_id", sort=False):
    rows = g[["path", "value"]].itertuples(index=False)
    cur_tg = None
    cur_min = None
    cur_max = None
    out = []
    for r in rows:
        if r.path == "TimeGroups/TimeGroup":
            if cur_tg is not None:
                out.append((cur_tg, int(cur_min), int(cur_max)))
            cur_tg = r.value
            cur_min = 0
            cur_max = 10**9
        elif r.path == "TimeGroups/TimeGroup/Minimum":
            cur_min = int(r.value)
        elif r.path == "TimeGroups/TimeGroup/Maximum":
            cur_max = int(r.value)
    if cur_tg is not None:
        out.append((cur_tg, int(cur_min), int(cur_max)))
    cid_to_tg_bounds[cid] = out

# %%
# 4) map each constraint -> each event 
applies_eg = df_constraint_applied[
    (df_constraint_applied["constraint_id"].isin(spread_cids)) &
    (df_constraint_applied["path"] == "AppliesTo/EventGroups/EventGroup")
][["constraint_id", "reference"]]

# map constraint -> events (list)
cid_to_eventgroups = applies_eg.groupby("constraint_id")["reference"].apply(list).to_dict()

# 5) event_group -> parent events, parent event -> sub-events
eg_to_events = (
    df_event_groups_membership.groupby("event_group_id")["event_id"].apply(set).to_dict()
)
parent_to_sub = (
    df_sub_event.groupby("parent_event_id")["sub_event_id"].apply(list).to_dict()
)

# 6) build index triples (cid, event_group, time_group)
triples = []
for cid in spread_cids: # for each constraint
    for eg in cid_to_eventgroups.get(cid, []): # for event group in constraint
        for tg, mn, mx in cid_to_tg_bounds.get(cid, []): # for time, max, min 
            triples.append((cid, eg, tg, int(mn), int(mx)))

#if not triples:
    #model.spread_events_penalty = pyo.Expression(expr=0.0)
    #return model.spread_events_penalty

#applies_eg
#cid_to_eventgroups
#eg_to_events
#parent_to_sub
#triples
# Out:
# [('SpreadEventsConstraint_CompositionAP_3_3',
#   'CompositionAP_3_3',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_CompositionAP_3_3',
#   'CompositionAP_3_3',
#   'Day_1',
#   0,
#   2),
#  ('SpreadEventsConstraint_CompositionAP_3_3',
#   'CompositionAP_3_3',
#   'Day_2',
#   0,
#   4),
#  ('SpreadEventsConstraint_CompositionAP_3_3',
#   'CompositionAP_3_3',
#   'Day_3',
#   0,
#   6),
#  ('SpreadEventsConstraint_CompositionAP_3_3',
#   'CompositionAP_3_3',
#   'Day_4',
#   0,
#   6),
#  ('SpreadEventsConstraint_WorldHistorySem2_0_2',
#   'WorldHistorySem2_0_2',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_WorldHistorySem2_0_2',
#   'WorldHistorySem2_0_2',
#   'Day_1',
#   0,
#   5),
#  ('SpreadEventsConstraint_WorldHistorySem2_0_2',
#   'WorldHistorySem2_0_2',
#   'Day_2',
#   0,
#   10),
#  ('SpreadEventsConstraint_WorldHistorySem2_0_2',
#   'WorldHistorySem2_0_2',
#   'Day_3',
#   0,
#   10),
#  ('SpreadEventsConstraint_WorldHistorySem2_0_2',
#   'WorldHistorySem2_0_2',
#   'Day_4',
#   0,
#   5),
#  ('SpreadEventsConstraint_Accounting-Advanced(H)_0_1',
#   'Accounting-Advanced(H)_0_1',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_Accounting-Advanced(H)_0_1',
#   'Accounting-Advanced(H)_0_1',
#   'Day_1',
#   1,
#   1),
#  ('SpreadEventsConstraint_Accounting-Advanced(H)_0_1',
#   'Accounting-Advanced(H)_0_1',
#   'Day_2',
#   1,
#   1),
#  ('SpreadEventsConstraint_Accounting-Advanced(H)_0_1',
#   'Accounting-Advanced(H)_0_1',
#   'Day_3',
#   1,
#   1),
#  ('SpreadEventsConstraint_Accounting-Advanced(H)_0_1',
#   'Accounting-Advanced(H)_0_1',
#   'Day_4',
#   1,
#   1),
#  ('SpreadEventsConstraint_AdvancedAlgebraSem2_3_1',
#   'AdvancedAlgebraSem2_3_1',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_AdvancedAlgebraSem2_3_1',
#   'AdvancedAlgebraSem2_3_1',
#   'Day_1',
#   2,
#   4),
#  ('SpreadEventsConstraint_AdvancedAlgebraSem2_3_1',
#   'AdvancedAlgebraSem2_3_1',
#   'Day_2',
#   0,
#   2),
#  ('SpreadEventsConstraint_AdvancedAlgebraSem2_3_1',
#   'AdvancedAlgebraSem2_3_1',
#   'Day_3',
#   2,
#   2),
#  ('SpreadEventsConstraint_AdvancedAlgebraSem2_3_1',
#   'AdvancedAlgebraSem2_3_1',
#   'Day_4',
#   4,
#   4),
#  ('SpreadEventsConstraint_Algebra2Sem2_0_1',
#   'Algebra2Sem2_0_1',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_Algebra2Sem2_0_1',
#   'Algebra2Sem2_0_1',
#   'Day_1',
#   2,
#   4),
#  ('SpreadEventsConstraint_Algebra2Sem2_0_1',
#   'Algebra2Sem2_0_1',
#   'Day_2',
#   0,
#   4),
#  ('SpreadEventsConstraint_Algebra2Sem2_0_1',
#   'Algebra2Sem2_0_1',
#   'Day_3',
#   2,
#   4),
#  ('SpreadEventsConstraint_Algebra2Sem2_0_1',
#   'Algebra2Sem2_0_1',
#   'Day_4',
#   2,
#   2),
#  ('SpreadEventsConstraint_ForensicScience_0_1',
#   'ForensicScience_0_1',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_ForensicScience_0_1',
#   'ForensicScience_0_1',
#   'Day_1',
#   0,
#   3),
#  ('SpreadEventsConstraint_ForensicScience_0_1',
#   'ForensicScience_0_1',
#   'Day_2',
#   0,
#   3),
#  ('SpreadEventsConstraint_ForensicScience_0_1',
#   'ForensicScience_0_1',
#   'Day_3',
#   0,
#   6),
#  ('SpreadEventsConstraint_ForensicScience_0_1',
#   'ForensicScience_0_1',
#   'Day_4',
#   0,
#   3),
#  ('SpreadEventsConstraint_AmericanLiterature2_4_2',
#   'AmericanLiterature2_4_2',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_AmericanLiterature2_4_2',
#   'AmericanLiterature2_4_2',
#   'Day_1',
#   0,
#   4),
#  ('SpreadEventsConstraint_AmericanLiterature2_4_2',
#   'AmericanLiterature2_4_2',
#   'Day_2',
#   0,
#   8),
#  ('SpreadEventsConstraint_AmericanLiterature2_4_2',
#   'AmericanLiterature2_4_2',
#   'Day_3',
#   0,
#   8),
#  ('SpreadEventsConstraint_AmericanLiterature2_4_2',
#   'AmericanLiterature2_4_2',
#   'Day_4',
#   0,
#   4),
#  ('SpreadEventsConstraint_ELL4_0_1', 'ELL4_0_1', 'Day_0', 0, 0),
#  ('SpreadEventsConstraint_ELL4_0_1', 'ELL4_0_1', 'Day_1', 1, 1),
#  ('SpreadEventsConstraint_ELL4_0_1', 'ELL4_0_1', 'Day_2', 1, 1),
#  ('SpreadEventsConstraint_ELL4_0_1', 'ELL4_0_1', 'Day_3', 1, 1),
#  ('SpreadEventsConstraint_ELL4_0_1', 'ELL4_0_1', 'Day_4', 2, 2),
#  ('SpreadEventsConstraint_SpeechPathologyD_0_1',
#   'SpeechPathologyD_0_1',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_SpeechPathologyD_0_1',
#   'SpeechPathologyD_0_1',
#   'Day_1',
#   0,
#   1),
#  ('SpreadEventsConstraint_SpeechPathologyD_0_1',
#   'SpeechPathologyD_0_1',
#   'Day_2',
#   0,
#   2),
#  ('SpreadEventsConstraint_SpeechPathologyD_0_1',
#   'SpeechPathologyD_0_1',
#   'Day_3',
#   0,
#   2),
#  ('SpreadEventsConstraint_SpeechPathologyD_0_1',
#   'SpeechPathologyD_0_1',
#   'Day_4',
#   0,
#   1),
#  ('SpreadEventsConstraint_ArtFoundations_0_1',
#   'ArtFoundations_0_1',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_ArtFoundations_0_1',
#   'ArtFoundations_0_1',
#   'Day_1',
#   2,
#   4),
#  ('SpreadEventsConstraint_ArtFoundations_0_1',
#   'ArtFoundations_0_1',
#   'Day_2',
#   0,
#   4),
#  ('SpreadEventsConstraint_ArtFoundations_0_1',
#   'ArtFoundations_0_1',
#   'Day_3',
#   2,
#   4),
#  ('SpreadEventsConstraint_ArtFoundations_0_1',
#   'ArtFoundations_0_1',
#   'Day_4',
#   2,
#   2),
#  ('SpreadEventsConstraint_Theater2_0_2', 'Theater2_0_2', 'Day_0', 0, 0),
#  ('SpreadEventsConstraint_Theater2_0_2', 'Theater2_0_2', 'Day_1', 0, 4),
#  ('SpreadEventsConstraint_Theater2_0_2', 'Theater2_0_2', 'Day_2', 0, 8),
#  ('SpreadEventsConstraint_Theater2_0_2', 'Theater2_0_2', 'Day_3', 0, 8),
#  ('SpreadEventsConstraint_Theater2_0_2', 'Theater2_0_2', 'Day_4', 0, 4),
#  ('SpreadEventsConstraint_BasicGeometrySem2_1_1',
#   'BasicGeometrySem2_1_1',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_BasicGeometrySem2_1_1',
#   'BasicGeometrySem2_1_1',
#   'Day_1',
#   2,
#   2),
#  ('SpreadEventsConstraint_BasicGeometrySem2_1_1',
#   'BasicGeometrySem2_1_1',
#   'Day_2',
#   2,
#   2),
#  ('SpreadEventsConstraint_BasicGeometrySem2_1_1',
#   'BasicGeometrySem2_1_1',
#   'Day_3',
#   2,
#   2),
#  ('SpreadEventsConstraint_BasicGeometrySem2_1_1',
#   'BasicGeometrySem2_1_1',
#   'Day_4',
#   4,
#   4),
#  ('SpreadEventsConstraint_WorldHistory(H)Sem2_2_2',
#   'WorldHistory(H)Sem2_2_2',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_WorldHistory(H)Sem2_2_2',
#   'WorldHistory(H)Sem2_2_2',
#   'Day_1',
#   0,
#   5),
#  ('SpreadEventsConstraint_WorldHistory(H)Sem2_2_2',
#   'WorldHistory(H)Sem2_2_2',
#   'Day_2',
#   0,
#   10),
#  ('SpreadEventsConstraint_WorldHistory(H)Sem2_2_2',
#   'WorldHistory(H)Sem2_2_2',
#   'Day_3',
#   0,
#   10),
#  ('SpreadEventsConstraint_WorldHistory(H)Sem2_2_2',
#   'WorldHistory(H)Sem2_2_2',
#   'Day_4',
#   0,
#   5),
#  ('SpreadEventsConstraint_AdvancedAlgebraSem2_1_1',
#   'AdvancedAlgebraSem2_1_1',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_AdvancedAlgebraSem2_1_1',
#   'AdvancedAlgebraSem2_1_1',
#   'Day_1',
#   2,
#   4),
#  ('SpreadEventsConstraint_AdvancedAlgebraSem2_1_1',
#   'AdvancedAlgebraSem2_1_1',
#   'Day_2',
#   0,
#   4),
#  ('SpreadEventsConstraint_AdvancedAlgebraSem2_1_1',
#   'AdvancedAlgebraSem2_1_1',
#   'Day_3',
#   2,
#   4),
#  ('SpreadEventsConstraint_AdvancedAlgebraSem2_1_1',
#   'AdvancedAlgebraSem2_1_1',
#   'Day_4',
#   2,
#   2),
#  ('SpreadEventsConstraint_Photojournalism_1_1',
#   'Photojournalism_1_1',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_Photojournalism_1_1',
#   'Photojournalism_1_1',
#   'Day_1',
#   0,
#   2),
#  ('SpreadEventsConstraint_Photojournalism_1_1',
#   'Photojournalism_1_1',
#   'Day_2',
#   0,
#   4),
#  ('SpreadEventsConstraint_Photojournalism_1_1',
#   'Photojournalism_1_1',
#   'Day_3',
#   0,
#   2),
#  ('SpreadEventsConstraint_Photojournalism_1_1',
#   'Photojournalism_1_1',
#   'Day_4',
#   2,
#   2),
#  ('SpreadEventsConstraint_HealthSciences-Advanced_0_2',
#   'HealthSciences-Advanced_0_2',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_HealthSciences-Advanced_0_2',
#   'HealthSciences-Advanced_0_2',
#   'Day_1',
#   0,
#   1),
#  ('SpreadEventsConstraint_HealthSciences-Advanced_0_2',
#   'HealthSciences-Advanced_0_2',
#   'Day_2',
#   0,
#   2),
#  ('SpreadEventsConstraint_HealthSciences-Advanced_0_2',
#   'HealthSciences-Advanced_0_2',
#   'Day_3',
#   0,
#   1),
#  ('SpreadEventsConstraint_HealthSciences-Advanced_0_2',
#   'HealthSciences-Advanced_0_2',
#   'Day_4',
#   1,
#   1),
#  ('SpreadEventsConstraint_Digitools_0_1', 'Digitools_0_1', 'Day_0', 0, 0),
#  ('SpreadEventsConstraint_Digitools_0_1', 'Digitools_0_1', 'Day_1', 2, 2),
#  ('SpreadEventsConstraint_Digitools_0_1', 'Digitools_0_1', 'Day_2', 2, 2),
#  ('SpreadEventsConstraint_Digitools_0_1', 'Digitools_0_1', 'Day_3', 2, 2),
#  ('SpreadEventsConstraint_Digitools_0_1', 'Digitools_0_1', 'Day_4', 2, 2),
#  ('SpreadEventsConstraint_Spanish3_0_1', 'Spanish3_0_1', 'Day_0', 0, 0),
#  ('SpreadEventsConstraint_Spanish3_0_1', 'Spanish3_0_1', 'Day_1', 2, 2),
#  ('SpreadEventsConstraint_Spanish3_0_1', 'Spanish3_0_1', 'Day_2', 2, 2),
#  ('SpreadEventsConstraint_Spanish3_0_1', 'Spanish3_0_1', 'Day_3', 2, 4),
#  ('SpreadEventsConstraint_Spanish3_0_1', 'Spanish3_0_1', 'Day_4', 2, 4),
#  ('SpreadEventsConstraint_Choir-VarsityShow_0_1',
#   'Choir-VarsityShow_0_1',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_Choir-VarsityShow_0_1',
#   'Choir-VarsityShow_0_1',
#   'Day_1',
#   1,
#   1),
#  ('SpreadEventsConstraint_Choir-VarsityShow_0_1',
#   'Choir-VarsityShow_0_1',
#   'Day_2',
#   1,
#   1),
#  ('SpreadEventsConstraint_Choir-VarsityShow_0_1',
#   'Choir-VarsityShow_0_1',
#   'Day_3',
#   1,
#   1),
#  ('SpreadEventsConstraint_Choir-VarsityShow_0_1',
#   'Choir-VarsityShow_0_1',
#   'Day_4',
#   1,
#   1),
#  ('SpreadEventsConstraint_MassCommunication_1_2',
#   'MassCommunication_1_2',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_MassCommunication_1_2',
#   'MassCommunication_1_2',
#   'Day_1',
#   0,
#   1),
#  ('SpreadEventsConstraint_MassCommunication_1_2',
#   'MassCommunication_1_2',
#   'Day_2',
#   0,
#   1),
#  ('SpreadEventsConstraint_MassCommunication_1_2',
#   'MassCommunication_1_2',
#   'Day_3',
#   1,
#   2),
#  ('SpreadEventsConstraint_MassCommunication_1_2',
#   'MassCommunication_1_2',
#   'Day_4',
#   1,
#   1),
#  ('SpreadEventsConstraint_SystemsTechnology_0_1',
#   'SystemsTechnology_0_1',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_SystemsTechnology_0_1',
#   'SystemsTechnology_0_1',
#   'Day_1',
#   1,
#   1),
#  ('SpreadEventsConstraint_SystemsTechnology_0_1',
#   'SystemsTechnology_0_1',
#   'Day_2',
#   1,
#   1),
#  ('SpreadEventsConstraint_SystemsTechnology_0_1',
#   'SystemsTechnology_0_1',
#   'Day_3',
#   1,
#   1),
#  ('SpreadEventsConstraint_SystemsTechnology_0_1',
#   'SystemsTechnology_0_1',
#   'Day_4',
#   1,
#   1),
#  ('SpreadEventsConstraint_Literature2(H)_1_2',
#   'Literature2(H)_1_2',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_Literature2(H)_1_2',
#   'Literature2(H)_1_2',
#   'Day_1',
#   0,
#   3),
#  ('SpreadEventsConstraint_Literature2(H)_1_2',
#   'Literature2(H)_1_2',
#   'Day_2',
#   0,
#   6),
#  ('SpreadEventsConstraint_Literature2(H)_1_2',
#   'Literature2(H)_1_2',
#   'Day_3',
#   0,
#   6),
#  ('SpreadEventsConstraint_Literature2(H)_1_2',
#   'Literature2(H)_1_2',
#   'Day_4',
#   0,
#   3),
#  ('SpreadEventsConstraint_CurrentEvents_2_1',
#   'CurrentEvents_2_1',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_CurrentEvents_2_1',
#   'CurrentEvents_2_1',
#   'Day_1',
#   0,
#   1),
#  ('SpreadEventsConstraint_CurrentEvents_2_1',
#   'CurrentEvents_2_1',
#   'Day_2',
#   0,
#   1),
#  ('SpreadEventsConstraint_CurrentEvents_2_1',
#   'CurrentEvents_2_1',
#   'Day_3',
#   0,
#   1),
#  ('SpreadEventsConstraint_CurrentEvents_2_1',
#   'CurrentEvents_2_1',
#   'Day_4',
#   1,
#   1),
#  ('SpreadEventsConstraint_Literature2(H)_2_2',
#   'Literature2(H)_2_2',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_Literature2(H)_2_2',
#   'Literature2(H)_2_2',
#   'Day_1',
#   0,
#   3),
#  ('SpreadEventsConstraint_Literature2(H)_2_2',
#   'Literature2(H)_2_2',
#   'Day_2',
#   0,
#   6),
#  ('SpreadEventsConstraint_Literature2(H)_2_2',
#   'Literature2(H)_2_2',
#   'Day_3',
#   0,
#   6),
#  ('SpreadEventsConstraint_Literature2(H)_2_2',
#   'Literature2(H)_2_2',
#   'Day_4',
#   0,
#   3),
#  ('SpreadEventsConstraint_MacintoshTechnician_0_1',
#   'MacintoshTechnician_0_1',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_MacintoshTechnician_0_1',
#   'MacintoshTechnician_0_1',
#   'Day_1',
#   0,
#   1),
#  ('SpreadEventsConstraint_MacintoshTechnician_0_1',
#   'MacintoshTechnician_0_1',
#   'Day_2',
#   0,
#   2),
#  ('SpreadEventsConstraint_MacintoshTechnician_0_1',
#   'MacintoshTechnician_0_1',
#   'Day_3',
#   0,
#   2),
#  ('SpreadEventsConstraint_MacintoshTechnician_0_1',
#   'MacintoshTechnician_0_1',
#   'Day_4',
#   0,
#   1),
#  ('SpreadEventsConstraint_Composition_5_2', 'Composition_5_2', 'Day_0', 0, 0),
#  ('SpreadEventsConstraint_Composition_5_2', 'Composition_5_2', 'Day_1', 0, 2),
#  ('SpreadEventsConstraint_Composition_5_2', 'Composition_5_2', 'Day_2', 0, 4),
#  ('SpreadEventsConstraint_Composition_5_2', 'Composition_5_2', 'Day_3', 0, 4),
#  ('SpreadEventsConstraint_Composition_5_2', 'Composition_5_2', 'Day_4', 0, 2),
#  ('SpreadEventsConstraint_AlgebraTrigonometry_2_1',
#   'AlgebraTrigonometry_2_1',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_AlgebraTrigonometry_2_1',
#   'AlgebraTrigonometry_2_1',
#   'Day_1',
#   2,
#   2),
#  ('SpreadEventsConstraint_AlgebraTrigonometry_2_1',
#   'AlgebraTrigonometry_2_1',
#   'Day_2',
#   2,
#   2),
#  ('SpreadEventsConstraint_AlgebraTrigonometry_2_1',
#   'AlgebraTrigonometry_2_1',
#   'Day_3',
#   2,
#   2),
#  ('SpreadEventsConstraint_AlgebraTrigonometry_2_1',
#   'AlgebraTrigonometry_2_1',
#   'Day_4',
#   4,
#   4),
#  ('SpreadEventsConstraint_CompositionAP_2_3',
#   'CompositionAP_2_3',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_CompositionAP_2_3',
#   'CompositionAP_2_3',
#   'Day_1',
#   0,
#   2),
#  ('SpreadEventsConstraint_CompositionAP_2_3',
#   'CompositionAP_2_3',
#   'Day_2',
#   0,
#   4),
#  ('SpreadEventsConstraint_CompositionAP_2_3',
#   'CompositionAP_2_3',
#   'Day_3',
#   0,
#   4),
#  ('SpreadEventsConstraint_CompositionAP_2_3',
#   'CompositionAP_2_3',
#   'Day_4',
#   0,
#   4),
#  ('SpreadEventsConstraint_English9_6_1', 'English9_6_1', 'Day_0', 0, 14),
#  ('SpreadEventsConstraint_English9_6_1', 'English9_6_1', 'Day_1', 0, 14),
#  ('SpreadEventsConstraint_English9_6_1', 'English9_6_1', 'Day_2', 0, 21),
#  ('SpreadEventsConstraint_English9_6_1', 'English9_6_1', 'Day_3', 0, 14),
#  ('SpreadEventsConstraint_English9_6_1', 'English9_6_1', 'Day_4', 0, 7),
#  ('SpreadEventsConstraint_Spanish3_2_1', 'Spanish3_2_1', 'Day_0', 0, 0),
#  ('SpreadEventsConstraint_Spanish3_2_1', 'Spanish3_2_1', 'Day_1', 3, 6),
#  ('SpreadEventsConstraint_Spanish3_2_1', 'Spanish3_2_1', 'Day_2', 0, 3),
#  ('SpreadEventsConstraint_Spanish3_2_1', 'Spanish3_2_1', 'Day_3', 3, 6),
#  ('SpreadEventsConstraint_Spanish3_2_1', 'Spanish3_2_1', 'Day_4', 3, 6),
#  ('SpreadEventsConstraint_VocabularyEnrichment_0_1',
#   'VocabularyEnrichment_0_1',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_VocabularyEnrichment_0_1',
#   'VocabularyEnrichment_0_1',
#   'Day_1',
#   0,
#   2),
#  ('SpreadEventsConstraint_VocabularyEnrichment_0_1',
#   'VocabularyEnrichment_0_1',
#   'Day_2',
#   0,
#   4),
#  ('SpreadEventsConstraint_VocabularyEnrichment_0_1',
#   'VocabularyEnrichment_0_1',
#   'Day_3',
#   0,
#   2),
#  ('SpreadEventsConstraint_VocabularyEnrichment_0_1',
#   'VocabularyEnrichment_0_1',
#   'Day_4',
#   2,
#   2),
#  ('SpreadEventsConstraint_Choir-WomensShow_0_1',
#   'Choir-WomensShow_0_1',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_Choir-WomensShow_0_1',
#   'Choir-WomensShow_0_1',
#   'Day_1',
#   0,
#   1),
#  ('SpreadEventsConstraint_Choir-WomensShow_0_1',
#   'Choir-WomensShow_0_1',
#   'Day_2',
#   0,
#   1),
#  ('SpreadEventsConstraint_Choir-WomensShow_0_1',
#   'Choir-WomensShow_0_1',
#   'Day_3',
#   1,
#   1),
#  ('SpreadEventsConstraint_Choir-WomensShow_0_1',
#   'Choir-WomensShow_0_1',
#   'Day_4',
#   1,
#   1),
#  ('SpreadEventsConstraint_ELL1_0_1', 'ELL1_0_1', 'Day_0', 0, 0),
#  ('SpreadEventsConstraint_ELL1_0_1', 'ELL1_0_1', 'Day_1', 1, 2),
#  ('SpreadEventsConstraint_ELL1_0_1', 'ELL1_0_1', 'Day_2', 1, 2),
#  ('SpreadEventsConstraint_ELL1_0_1', 'ELL1_0_1', 'Day_3', 1, 1),
#  ('SpreadEventsConstraint_ELL1_0_1', 'ELL1_0_1', 'Day_4', 1, 1),
#  ('SpreadEventsConstraint_WorldHistorySem2_1_2',
#   'WorldHistorySem2_1_2',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_WorldHistorySem2_1_2',
#   'WorldHistorySem2_1_2',
#   'Day_1',
#   0,
#   5),
#  ('SpreadEventsConstraint_WorldHistorySem2_1_2',
#   'WorldHistorySem2_1_2',
#   'Day_2',
#   0,
#   10),
#  ('SpreadEventsConstraint_WorldHistorySem2_1_2',
#   'WorldHistorySem2_1_2',
#   'Day_3',
#   0,
#   10),
#  ('SpreadEventsConstraint_WorldHistorySem2_1_2',
#   'WorldHistorySem2_1_2',
#   'Day_4',
#   0,
#   5),
#  ('SpreadEventsConstraint_German5(H)_0_1', 'German5(H)_0_1', 'Day_0', 0, 0),
#  ('SpreadEventsConstraint_German5(H)_0_1', 'German5(H)_0_1', 'Day_1', 1, 1),
#  ('SpreadEventsConstraint_German5(H)_0_1', 'German5(H)_0_1', 'Day_2', 1, 1),
#  ('SpreadEventsConstraint_German5(H)_0_1', 'German5(H)_0_1', 'Day_3', 1, 1),
#  ('SpreadEventsConstraint_German5(H)_0_1', 'German5(H)_0_1', 'Day_4', 1, 1),
#  ('SpreadEventsConstraint_GlobalIntolerance_1_2',
#   'GlobalIntolerance_1_2',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_GlobalIntolerance_1_2',
#   'GlobalIntolerance_1_2',
#   'Day_1',
#   0,
#   3),
#  ('SpreadEventsConstraint_GlobalIntolerance_1_2',
#   'GlobalIntolerance_1_2',
#   'Day_2',
#   0,
#   6),
#  ('SpreadEventsConstraint_GlobalIntolerance_1_2',
#   'GlobalIntolerance_1_2',
#   'Day_3',
#   0,
#   6),
#  ('SpreadEventsConstraint_GlobalIntolerance_1_2',
#   'GlobalIntolerance_1_2',
#   'Day_4',
#   0,
#   3),
#  ('SpreadEventsConstraint_PoliceandSociety_0_2',
#   'PoliceandSociety_0_2',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_PoliceandSociety_0_2',
#   'PoliceandSociety_0_2',
#   'Day_1',
#   0,
#   0),
#  ('SpreadEventsConstraint_PoliceandSociety_0_2',
#   'PoliceandSociety_0_2',
#   'Day_2',
#   0,
#   0),
#  ('SpreadEventsConstraint_PoliceandSociety_0_2',
#   'PoliceandSociety_0_2',
#   'Day_3',
#   2,
#   2),
#  ('SpreadEventsConstraint_PoliceandSociety_0_2',
#   'PoliceandSociety_0_2',
#   'Day_4',
#   0,
#   0),
#  ('SpreadEventsConstraint_LearningStrategies_0_1',
#   'LearningStrategies_0_1',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_LearningStrategies_0_1',
#   'LearningStrategies_0_1',
#   'Day_1',
#   0,
#   4),
#  ('SpreadEventsConstraint_LearningStrategies_0_1',
#   'LearningStrategies_0_1',
#   'Day_2',
#   0,
#   8),
#  ('SpreadEventsConstraint_LearningStrategies_0_1',
#   'LearningStrategies_0_1',
#   'Day_3',
#   0,
#   8),
#  ('SpreadEventsConstraint_LearningStrategies_0_1',
#   'LearningStrategies_0_1',
#   'Day_4',
#   0,
#   4),
#  ('SpreadEventsConstraint_AdvancedDebate_0_1',
#   'AdvancedDebate_0_1',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_AdvancedDebate_0_1',
#   'AdvancedDebate_0_1',
#   'Day_1',
#   0,
#   1),
#  ('SpreadEventsConstraint_AdvancedDebate_0_1',
#   'AdvancedDebate_0_1',
#   'Day_2',
#   0,
#   2),
#  ('SpreadEventsConstraint_AdvancedDebate_0_1',
#   'AdvancedDebate_0_1',
#   'Day_3',
#   0,
#   2),
#  ('SpreadEventsConstraint_AdvancedDebate_0_1',
#   'AdvancedDebate_0_1',
#   'Day_4',
#   0,
#   1),
#  ('SpreadEventsConstraint_AmericanGovernment_1_2',
#   'AmericanGovernment_1_2',
#   'Day_0',
#   0,
#   1),
#  ('SpreadEventsConstraint_AmericanGovernment_1_2',
#   'AmericanGovernment_1_2',
#   'Day_1',
#   1,
#   1),
#  ('SpreadEventsConstraint_AmericanGovernment_1_2',
#   'AmericanGovernment_1_2',
#   'Day_2',
#   1,
#   1),
#  ('SpreadEventsConstraint_AmericanGovernment_1_2',
#   'AmericanGovernment_1_2',
#   'Day_3',
#   1,
#   1),
#  ('SpreadEventsConstraint_AmericanGovernment_1_2',
#   'AmericanGovernment_1_2',
#   'Day_4',
#   0,
#   1),
#  ('SpreadEventsConstraint_PersonalFinance_1_2',
#   'PersonalFinance_1_2',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_PersonalFinance_1_2',
#   'PersonalFinance_1_2',
#   'Day_1',
#   0,
#   1),
#  ('SpreadEventsConstraint_PersonalFinance_1_2',
#   'PersonalFinance_1_2',
#   'Day_2',
#   0,
#   2),
#  ('SpreadEventsConstraint_PersonalFinance_1_2',
#   'PersonalFinance_1_2',
#   'Day_3',
#   0,
#   2),
#  ('SpreadEventsConstraint_PersonalFinance_1_2',
#   'PersonalFinance_1_2',
#   'Day_4',
#   0,
#   1),
#  ('SpreadEventsConstraint_Humanities_2_2', 'Humanities_2_2', 'Day_0', 0, 0),
#  ('SpreadEventsConstraint_Humanities_2_2', 'Humanities_2_2', 'Day_1', 0, 1),
#  ('SpreadEventsConstraint_Humanities_2_2', 'Humanities_2_2', 'Day_2', 0, 2),
#  ('SpreadEventsConstraint_Humanities_2_2', 'Humanities_2_2', 'Day_3', 0, 2),
#  ('SpreadEventsConstraint_Humanities_2_2', 'Humanities_2_2', 'Day_4', 0, 1),
#  ('SpreadEventsConstraint_GraphicDesign_0_1',
#   'GraphicDesign_0_1',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_GraphicDesign_0_1',
#   'GraphicDesign_0_1',
#   'Day_1',
#   0,
#   1),
#  ('SpreadEventsConstraint_GraphicDesign_0_1',
#   'GraphicDesign_0_1',
#   'Day_2',
#   0,
#   1),
#  ('SpreadEventsConstraint_GraphicDesign_0_1',
#   'GraphicDesign_0_1',
#   'Day_3',
#   1,
#   1),
#  ('SpreadEventsConstraint_GraphicDesign_0_1',
#   'GraphicDesign_0_1',
#   'Day_4',
#   1,
#   1),
#  ('SpreadEventsConstraint_ArtFoundations_1_1',
#   'ArtFoundations_1_1',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_ArtFoundations_1_1',
#   'ArtFoundations_1_1',
#   'Day_1',
#   2,
#   2),
#  ('SpreadEventsConstraint_ArtFoundations_1_1',
#   'ArtFoundations_1_1',
#   'Day_2',
#   2,
#   2),
#  ('SpreadEventsConstraint_ArtFoundations_1_1',
#   'ArtFoundations_1_1',
#   'Day_3',
#   2,
#   2),
#  ('SpreadEventsConstraint_ArtFoundations_1_1',
#   'ArtFoundations_1_1',
#   'Day_4',
#   2,
#   2),
#  ('SpreadEventsConstraint_LearningStrategiesB_0_1',
#   'LearningStrategiesB_0_1',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_LearningStrategiesB_0_1',
#   'LearningStrategiesB_0_1',
#   'Day_1',
#   0,
#   1),
#  ('SpreadEventsConstraint_LearningStrategiesB_0_1',
#   'LearningStrategiesB_0_1',
#   'Day_2',
#   0,
#   2),
#  ('SpreadEventsConstraint_LearningStrategiesB_0_1',
#   'LearningStrategiesB_0_1',
#   'Day_3',
#   0,
#   2),
#  ('SpreadEventsConstraint_LearningStrategiesB_0_1',
#   'LearningStrategiesB_0_1',
#   'Day_4',
#   0,
#   1),
#  ('SpreadEventsConstraint_Marketing2_0_2', 'Marketing2_0_2', 'Day_0', 0, 0),
#  ('SpreadEventsConstraint_Marketing2_0_2', 'Marketing2_0_2', 'Day_1', 0, 3),
#  ('SpreadEventsConstraint_Marketing2_0_2', 'Marketing2_0_2', 'Day_2', 0, 6),
#  ('SpreadEventsConstraint_Marketing2_0_2', 'Marketing2_0_2', 'Day_3', 0, 9),
#  ('SpreadEventsConstraint_Marketing2_0_2', 'Marketing2_0_2', 'Day_4', 0, 9),
#  ('SpreadEventsConstraint_Biology(H)Sem2_1_1',
#   'Biology(H)Sem2_1_1',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_Biology(H)Sem2_1_1',
#   'Biology(H)Sem2_1_1',
#   'Day_1',
#   0,
#   3),
#  ('SpreadEventsConstraint_Biology(H)Sem2_1_1',
#   'Biology(H)Sem2_1_1',
#   'Day_2',
#   0,
#   6),
#  ('SpreadEventsConstraint_Biology(H)Sem2_1_1',
#   'Biology(H)Sem2_1_1',
#   'Day_3',
#   0,
#   6),
#  ('SpreadEventsConstraint_Biology(H)Sem2_1_1',
#   'Biology(H)Sem2_1_1',
#   'Day_4',
#   0,
#   3),
#  ('SpreadEventsConstraint_GeographyAP_0_2', 'GeographyAP_0_2', 'Day_0', 0, 0),
#  ('SpreadEventsConstraint_GeographyAP_0_2', 'GeographyAP_0_2', 'Day_1', 0, 4),
#  ('SpreadEventsConstraint_GeographyAP_0_2', 'GeographyAP_0_2', 'Day_2', 0, 8),
#  ('SpreadEventsConstraint_GeographyAP_0_2', 'GeographyAP_0_2', 'Day_3', 0, 8),
#  ('SpreadEventsConstraint_GeographyAP_0_2', 'GeographyAP_0_2', 'Day_4', 0, 4),
#  ('SpreadEventsConstraint_PersonalFinance_0_2',
#   'PersonalFinance_0_2',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_PersonalFinance_0_2',
#   'PersonalFinance_0_2',
#   'Day_1',
#   0,
#   4),
#  ('SpreadEventsConstraint_PersonalFinance_0_2',
#   'PersonalFinance_0_2',
#   'Day_2',
#   0,
#   8),
#  ('SpreadEventsConstraint_PersonalFinance_0_2',
#   'PersonalFinance_0_2',
#   'Day_3',
#   0,
#   8),
#  ('SpreadEventsConstraint_PersonalFinance_0_2',
#   'PersonalFinance_0_2',
#   'Day_4',
#   0,
#   4),
#  ('SpreadEventsConstraint_SportsMedicine_1_2',
#   'SportsMedicine_1_2',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_SportsMedicine_1_2',
#   'SportsMedicine_1_2',
#   'Day_1',
#   0,
#   1),
#  ('SpreadEventsConstraint_SportsMedicine_1_2',
#   'SportsMedicine_1_2',
#   'Day_2',
#   1,
#   2),
#  ('SpreadEventsConstraint_SportsMedicine_1_2',
#   'SportsMedicine_1_2',
#   'Day_3',
#   0,
#   1),
#  ('SpreadEventsConstraint_SportsMedicine_1_2',
#   'SportsMedicine_1_2',
#   'Day_4',
#   0,
#   1),
#  ('SpreadEventsConstraint_Orchestra-Freshman_0_1',
#   'Orchestra-Freshman_0_1',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_Orchestra-Freshman_0_1',
#   'Orchestra-Freshman_0_1',
#   'Day_1',
#   0,
#   1),
#  ('SpreadEventsConstraint_Orchestra-Freshman_0_1',
#   'Orchestra-Freshman_0_1',
#   'Day_2',
#   0,
#   2),
#  ('SpreadEventsConstraint_Orchestra-Freshman_0_1',
#   'Orchestra-Freshman_0_1',
#   'Day_3',
#   0,
#   2),
#  ('SpreadEventsConstraint_Orchestra-Freshman_0_1',
#   'Orchestra-Freshman_0_1',
#   'Day_4',
#   0,
#   1),
#  ('SpreadEventsConstraint_Photojournalism_0_1',
#   'Photojournalism_0_1',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_Photojournalism_0_1',
#   'Photojournalism_0_1',
#   'Day_1',
#   2,
#   2),
#  ('SpreadEventsConstraint_Photojournalism_0_1',
#   'Photojournalism_0_1',
#   'Day_2',
#   2,
#   2),
#  ('SpreadEventsConstraint_Photojournalism_0_1',
#   'Photojournalism_0_1',
#   'Day_3',
#   0,
#   2),
#  ('SpreadEventsConstraint_Photojournalism_0_1',
#   'Photojournalism_0_1',
#   'Day_4',
#   0,
#   2),
#  ('SpreadEventsConstraint_German2_0_1', 'German2_0_1', 'Day_0', 0, 0),
#  ('SpreadEventsConstraint_German2_0_1', 'German2_0_1', 'Day_1', 2, 2),
#  ('SpreadEventsConstraint_German2_0_1', 'German2_0_1', 'Day_2', 2, 2),
#  ('SpreadEventsConstraint_German2_0_1', 'German2_0_1', 'Day_3', 2, 4),
#  ('SpreadEventsConstraint_German2_0_1', 'German2_0_1', 'Day_4', 2, 4),
#  ('SpreadEventsConstraint_Pre-Calculus_2_2',
#   'Pre-Calculus_2_2',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_Pre-Calculus_2_2',
#   'Pre-Calculus_2_2',
#   'Day_1',
#   3,
#   3),
#  ('SpreadEventsConstraint_Pre-Calculus_2_2',
#   'Pre-Calculus_2_2',
#   'Day_2',
#   3,
#   3),
#  ('SpreadEventsConstraint_Pre-Calculus_2_2',
#   'Pre-Calculus_2_2',
#   'Day_3',
#   3,
#   3),
#  ('SpreadEventsConstraint_Pre-Calculus_2_2',
#   'Pre-Calculus_2_2',
#   'Day_4',
#   3,
#   3),
#  ('SpreadEventsConstraint_Spanish2_3_1', 'Spanish2_3_1', 'Day_0', 0, 0),
#  ('SpreadEventsConstraint_Spanish2_3_1', 'Spanish2_3_1', 'Day_1', 3, 3),
#  ('SpreadEventsConstraint_Spanish2_3_1', 'Spanish2_3_1', 'Day_2', 3, 3),
#  ('SpreadEventsConstraint_Spanish2_3_1', 'Spanish2_3_1', 'Day_3', 3, 3),
#  ('SpreadEventsConstraint_Spanish2_3_1', 'Spanish2_3_1', 'Day_4', 3, 3),
#  ('SpreadEventsConstraint_StatisticsAP_0_3',
#   'StatisticsAP_0_3',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_StatisticsAP_0_3',
#   'StatisticsAP_0_3',
#   'Day_1',
#   0,
#   2),
#  ('SpreadEventsConstraint_StatisticsAP_0_3',
#   'StatisticsAP_0_3',
#   'Day_2',
#   0,
#   4),
#  ('SpreadEventsConstraint_StatisticsAP_0_3',
#   'StatisticsAP_0_3',
#   'Day_3',
#   0,
#   4),
#  ('SpreadEventsConstraint_StatisticsAP_0_3',
#   'StatisticsAP_0_3',
#   'Day_4',
#   0,
#   2),
#  ('SpreadEventsConstraint_WorldHistorySem2_3_2',
#   'WorldHistorySem2_3_2',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_WorldHistorySem2_3_2',
#   'WorldHistorySem2_3_2',
#   'Day_1',
#   1,
#   1),
#  ('SpreadEventsConstraint_WorldHistorySem2_3_2',
#   'WorldHistorySem2_3_2',
#   'Day_2',
#   1,
#   1),
#  ('SpreadEventsConstraint_WorldHistorySem2_3_2',
#   'WorldHistorySem2_3_2',
#   'Day_3',
#   0,
#   1),
#  ('SpreadEventsConstraint_WorldHistorySem2_3_2',
#   'WorldHistorySem2_3_2',
#   'Day_4',
#   0,
#   1),
#  ('SpreadEventsConstraint_Literature2_4_1', 'Literature2_4_1', 'Day_0', 0, 0),
#  ('SpreadEventsConstraint_Literature2_4_1', 'Literature2_4_1', 'Day_1', 0, 5),
#  ('SpreadEventsConstraint_Literature2_4_1', 'Literature2_4_1', 'Day_2', 0, 10),
#  ('SpreadEventsConstraint_Literature2_4_1', 'Literature2_4_1', 'Day_3', 0, 10),
#  ('SpreadEventsConstraint_Literature2_4_1', 'Literature2_4_1', 'Day_4', 0, 5),
#  ('SpreadEventsConstraint_Spanish2_4_1', 'Spanish2_4_1', 'Day_0', 0, 0),
#  ('SpreadEventsConstraint_Spanish2_4_1', 'Spanish2_4_1', 'Day_1', 3, 6),
#  ('SpreadEventsConstraint_Spanish2_4_1', 'Spanish2_4_1', 'Day_2', 0, 6),
#  ('SpreadEventsConstraint_Spanish2_4_1', 'Spanish2_4_1', 'Day_3', 0, 6),
#  ('SpreadEventsConstraint_Spanish2_4_1', 'Spanish2_4_1', 'Day_4', 3, 6),
#  ('SpreadEventsConstraint_Magazine_0_2', 'Magazine_0_2', 'Day_0', 0, 0),
#  ('SpreadEventsConstraint_Magazine_0_2', 'Magazine_0_2', 'Day_1', 0, 1),
#  ('SpreadEventsConstraint_Magazine_0_2', 'Magazine_0_2', 'Day_2', 0, 1),
#  ('SpreadEventsConstraint_Magazine_0_2', 'Magazine_0_2', 'Day_3', 1, 1),
#  ('SpreadEventsConstraint_Magazine_0_2', 'Magazine_0_2', 'Day_4', 1, 1),
#  ('SpreadEventsConstraint_Spanish3_1_1', 'Spanish3_1_1', 'Day_0', 0, 0),
#  ('SpreadEventsConstraint_Spanish3_1_1', 'Spanish3_1_1', 'Day_1', 2, 4),
#  ('SpreadEventsConstraint_Spanish3_1_1', 'Spanish3_1_1', 'Day_2', 0, 4),
#  ('SpreadEventsConstraint_Spanish3_1_1', 'Spanish3_1_1', 'Day_3', 2, 4),
#  ('SpreadEventsConstraint_Spanish3_1_1', 'Spanish3_1_1', 'Day_4', 2, 2),
#  ('SpreadEventsConstraint_CompositionAP_0_3',
#   'CompositionAP_0_3',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_CompositionAP_0_3',
#   'CompositionAP_0_3',
#   'Day_1',
#   0,
#   2),
#  ('SpreadEventsConstraint_CompositionAP_0_3',
#   'CompositionAP_0_3',
#   'Day_2',
#   0,
#   4),
#  ('SpreadEventsConstraint_CompositionAP_0_3',
#   'CompositionAP_0_3',
#   'Day_3',
#   0,
#   2),
#  ('SpreadEventsConstraint_CompositionAP_0_3',
#   'CompositionAP_0_3',
#   'Day_4',
#   2,
#   4),
#  ('SpreadEventsConstraint_Composition_4_2', 'Composition_4_2', 'Day_0', 0, 0),
#  ('SpreadEventsConstraint_Composition_4_2', 'Composition_4_2', 'Day_1', 0, 1),
#  ('SpreadEventsConstraint_Composition_4_2', 'Composition_4_2', 'Day_2', 0, 2),
#  ('SpreadEventsConstraint_Composition_4_2', 'Composition_4_2', 'Day_3', 0, 2),
#  ('SpreadEventsConstraint_Composition_4_2', 'Composition_4_2', 'Day_4', 0, 1),
#  ('SpreadEventsConstraint_GlobalGeography_1_2',
#   'GlobalGeography_1_2',
#   'Day_0',
#   0,
#   2),
#  ('SpreadEventsConstraint_GlobalGeography_1_2',
#   'GlobalGeography_1_2',
#   'Day_1',
#   0,
#   2),
#  ('SpreadEventsConstraint_GlobalGeography_1_2',
#   'GlobalGeography_1_2',
#   'Day_2',
#   0,
#   4),
#  ('SpreadEventsConstraint_GlobalGeography_1_2',
#   'GlobalGeography_1_2',
#   'Day_3',
#   0,
#   4),
#  ('SpreadEventsConstraint_GlobalGeography_1_2',
#   'GlobalGeography_1_2',
#   'Day_4',
#   0,
#   2),
#  ('SpreadEventsConstraint_Yearbook_0_2', 'Yearbook_0_2', 'Day_0', 0, 0),
#  ('SpreadEventsConstraint_Yearbook_0_2', 'Yearbook_0_2', 'Day_1', 0, 1),
#  ('SpreadEventsConstraint_Yearbook_0_2', 'Yearbook_0_2', 'Day_2', 0, 1),
#  ('SpreadEventsConstraint_Yearbook_0_2', 'Yearbook_0_2', 'Day_3', 1, 1),
#  ('SpreadEventsConstraint_Yearbook_0_2', 'Yearbook_0_2', 'Day_4', 1, 1),
#  ('SpreadEventsConstraint_Theater_0_1', 'Theater_0_1', 'Day_0', 0, 0),
#  ('SpreadEventsConstraint_Theater_0_1', 'Theater_0_1', 'Day_1', 1, 1),
#  ('SpreadEventsConstraint_Theater_0_1', 'Theater_0_1', 'Day_2', 1, 1),
#  ('SpreadEventsConstraint_Theater_0_1', 'Theater_0_1', 'Day_3', 1, 1),
#  ('SpreadEventsConstraint_Theater_0_1', 'Theater_0_1', 'Day_4', 1, 1),
#  ('SpreadEventsConstraint_Biology(H)Sem2_0_1',
#   'Biology(H)Sem2_0_1',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_Biology(H)Sem2_0_1',
#   'Biology(H)Sem2_0_1',
#   'Day_1',
#   0,
#   3),
#  ('SpreadEventsConstraint_Biology(H)Sem2_0_1',
#   'Biology(H)Sem2_0_1',
#   'Day_2',
#   0,
#   6),
#  ('SpreadEventsConstraint_Biology(H)Sem2_0_1',
#   'Biology(H)Sem2_0_1',
#   'Day_3',
#   0,
#   6),
#  ('SpreadEventsConstraint_Biology(H)Sem2_0_1',
#   'Biology(H)Sem2_0_1',
#   'Day_4',
#   0,
#   3),
#  ('SpreadEventsConstraint_Composition_3_2', 'Composition_3_2', 'Day_0', 0, 0),
#  ('SpreadEventsConstraint_Composition_3_2', 'Composition_3_2', 'Day_1', 0, 2),
#  ('SpreadEventsConstraint_Composition_3_2', 'Composition_3_2', 'Day_2', 0, 4),
#  ('SpreadEventsConstraint_Composition_3_2', 'Composition_3_2', 'Day_3', 0, 2),
#  ('SpreadEventsConstraint_Composition_3_2', 'Composition_3_2', 'Day_4', 2, 2),
#  ('SpreadEventsConstraint_WorldHistory(H)Sem2_0_2',
#   'WorldHistory(H)Sem2_0_2',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_WorldHistory(H)Sem2_0_2',
#   'WorldHistory(H)Sem2_0_2',
#   'Day_1',
#   0,
#   5),
#  ('SpreadEventsConstraint_WorldHistory(H)Sem2_0_2',
#   'WorldHistory(H)Sem2_0_2',
#   'Day_2',
#   0,
#   10),
#  ('SpreadEventsConstraint_WorldHistory(H)Sem2_0_2',
#   'WorldHistory(H)Sem2_0_2',
#   'Day_3',
#   0,
#   10),
#  ('SpreadEventsConstraint_WorldHistory(H)Sem2_0_2',
#   'WorldHistory(H)Sem2_0_2',
#   'Day_4',
#   0,
#   5),
#  ('SpreadEventsConstraint_Algebra1(S1)-YearCourse_0_1',
#   'Algebra1(S1)-YearCourse_0_1',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_Algebra1(S1)-YearCourse_0_1',
#   'Algebra1(S1)-YearCourse_0_1',
#   'Day_1',
#   1,
#   2),
#  ('SpreadEventsConstraint_Algebra1(S1)-YearCourse_0_1',
#   'Algebra1(S1)-YearCourse_0_1',
#   'Day_2',
#   1,
#   2),
#  ('SpreadEventsConstraint_Algebra1(S1)-YearCourse_0_1',
#   'Algebra1(S1)-YearCourse_0_1',
#   'Day_3',
#   1,
#   1),
#  ('SpreadEventsConstraint_Algebra1(S1)-YearCourse_0_1',
#   'Algebra1(S1)-YearCourse_0_1',
#   'Day_4',
#   1,
#   1),
#  ('SpreadEventsConstraint_Composition_2_2', 'Composition_2_2', 'Day_0', 0, 0),
#  ('SpreadEventsConstraint_Composition_2_2', 'Composition_2_2', 'Day_1', 0, 2),
#  ('SpreadEventsConstraint_Composition_2_2', 'Composition_2_2', 'Day_2', 0, 4),
#  ('SpreadEventsConstraint_Composition_2_2', 'Composition_2_2', 'Day_3', 0, 4),
#  ('SpreadEventsConstraint_Composition_2_2', 'Composition_2_2', 'Day_4', 0, 2),
#  ('SpreadEventsConstraint_GeometrySem2_2_1',
#   'GeometrySem2_2_1',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_GeometrySem2_2_1',
#   'GeometrySem2_2_1',
#   'Day_1',
#   3,
#   6),
#  ('SpreadEventsConstraint_GeometrySem2_2_1',
#   'GeometrySem2_2_1',
#   'Day_2',
#   0,
#   6),
#  ('SpreadEventsConstraint_GeometrySem2_2_1',
#   'GeometrySem2_2_1',
#   'Day_3',
#   0,
#   6),
#  ('SpreadEventsConstraint_GeometrySem2_2_1',
#   'GeometrySem2_2_1',
#   'Day_4',
#   3,
#   6),
#  ('SpreadEventsConstraint_Spanish2_0_1', 'Spanish2_0_1', 'Day_0', 0, 0),
#  ('SpreadEventsConstraint_Spanish2_0_1', 'Spanish2_0_1', 'Day_1', 3, 6),
#  ('SpreadEventsConstraint_Spanish2_0_1', 'Spanish2_0_1', 'Day_2', 0, 6),
#  ('SpreadEventsConstraint_Spanish2_0_1', 'Spanish2_0_1', 'Day_3', 0, 6),
#  ('SpreadEventsConstraint_Spanish2_0_1', 'Spanish2_0_1', 'Day_4', 3, 6),
#  ('SpreadEventsConstraint_GlobalGeography_0_2',
#   'GlobalGeography_0_2',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_GlobalGeography_0_2',
#   'GlobalGeography_0_2',
#   'Day_1',
#   3,
#   3),
#  ('SpreadEventsConstraint_GlobalGeography_0_2',
#   'GlobalGeography_0_2',
#   'Day_2',
#   3,
#   3),
#  ('SpreadEventsConstraint_GlobalGeography_0_2',
#   'GlobalGeography_0_2',
#   'Day_3',
#   0,
#   3),
#  ('SpreadEventsConstraint_GlobalGeography_0_2',
#   'GlobalGeography_0_2',
#   'Day_4',
#   0,
#   3),
#  ('SpreadEventsConstraint_AmericanLiterature2_0_2',
#   'AmericanLiterature2_0_2',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_AmericanLiterature2_0_2',
#   'AmericanLiterature2_0_2',
#   'Day_1',
#   0,
#   3),
#  ('SpreadEventsConstraint_AmericanLiterature2_0_2',
#   'AmericanLiterature2_0_2',
#   'Day_2',
#   0,
#   6),
#  ('SpreadEventsConstraint_AmericanLiterature2_0_2',
#   'AmericanLiterature2_0_2',
#   'Day_3',
#   0,
#   6),
#  ('SpreadEventsConstraint_AmericanLiterature2_0_2',
#   'AmericanLiterature2_0_2',
#   'Day_4',
#   0,
#   3),
#  ('SpreadEventsConstraint_SpeechPathologyB_0_1',
#   'SpeechPathologyB_0_1',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_SpeechPathologyB_0_1',
#   'SpeechPathologyB_0_1',
#   'Day_1',
#   0,
#   1),
#  ('SpreadEventsConstraint_SpeechPathologyB_0_1',
#   'SpeechPathologyB_0_1',
#   'Day_2',
#   0,
#   2),
#  ('SpreadEventsConstraint_SpeechPathologyB_0_1',
#   'SpeechPathologyB_0_1',
#   'Day_3',
#   0,
#   2),
#  ('SpreadEventsConstraint_SpeechPathologyB_0_1',
#   'SpeechPathologyB_0_1',
#   'Day_4',
#   0,
#   1),
#  ('SpreadEventsConstraint_CurrentEvents_2_2',
#   'CurrentEvents_2_2',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_CurrentEvents_2_2',
#   'CurrentEvents_2_2',
#   'Day_1',
#   0,
#   1),
#  ('SpreadEventsConstraint_CurrentEvents_2_2',
#   'CurrentEvents_2_2',
#   'Day_2',
#   0,
#   1),
#  ('SpreadEventsConstraint_CurrentEvents_2_2',
#   'CurrentEvents_2_2',
#   'Day_3',
#   0,
#   1),
#  ('SpreadEventsConstraint_CurrentEvents_2_2',
#   'CurrentEvents_2_2',
#   'Day_4',
#   1,
#   1),
#  ('SpreadEventsConstraint_MediaConvergence_1_1',
#   'MediaConvergence_1_1',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_MediaConvergence_1_1',
#   'MediaConvergence_1_1',
#   'Day_1',
#   1,
#   1),
#  ('SpreadEventsConstraint_MediaConvergence_1_1',
#   'MediaConvergence_1_1',
#   'Day_2',
#   1,
#   2),
#  ('SpreadEventsConstraint_MediaConvergence_1_1',
#   'MediaConvergence_1_1',
#   'Day_3',
#   1,
#   2),
#  ('SpreadEventsConstraint_MediaConvergence_1_1',
#   'MediaConvergence_1_1',
#   'Day_4',
#   1,
#   1),
#  ('SpreadEventsConstraint_Pre-Calculus_0_2',
#   'Pre-Calculus_0_2',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_Pre-Calculus_0_2',
#   'Pre-Calculus_0_2',
#   'Day_1',
#   1,
#   1),
#  ('SpreadEventsConstraint_Pre-Calculus_0_2',
#   'Pre-Calculus_0_2',
#   'Day_2',
#   1,
#   1),
#  ('SpreadEventsConstraint_Pre-Calculus_0_2',
#   'Pre-Calculus_0_2',
#   'Day_3',
#   1,
#   1),
#  ('SpreadEventsConstraint_Pre-Calculus_0_2',
#   'Pre-Calculus_0_2',
#   'Day_4',
#   1,
#   1),
#  ('SpreadEventsConstraint_Electronics2_0_1',
#   'Electronics2_0_1',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_Electronics2_0_1',
#   'Electronics2_0_1',
#   'Day_1',
#   1,
#   1),
#  ('SpreadEventsConstraint_Electronics2_0_1',
#   'Electronics2_0_1',
#   'Day_2',
#   1,
#   1),
#  ('SpreadEventsConstraint_Electronics2_0_1',
#   'Electronics2_0_1',
#   'Day_3',
#   1,
#   1),
#  ('SpreadEventsConstraint_Electronics2_0_1',
#   'Electronics2_0_1',
#   'Day_4',
#   1,
#   1),
#  ('SpreadEventsConstraint_Marketing2_1_2', 'Marketing2_1_2', 'Day_0', 0, 0),
#  ('SpreadEventsConstraint_Marketing2_1_2', 'Marketing2_1_2', 'Day_1', 0, 2),
#  ('SpreadEventsConstraint_Marketing2_1_2', 'Marketing2_1_2', 'Day_2', 0, 4),
#  ('SpreadEventsConstraint_Marketing2_1_2', 'Marketing2_1_2', 'Day_3', 0, 4),
#  ('SpreadEventsConstraint_Marketing2_1_2', 'Marketing2_1_2', 'Day_4', 0, 2),
#  ('SpreadEventsConstraint_InformationTechnology1_2_1',
#   'InformationTechnology1_2_1',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_InformationTechnology1_2_1',
#   'InformationTechnology1_2_1',
#   'Day_1',
#   2,
#   4),
#  ('SpreadEventsConstraint_InformationTechnology1_2_1',
#   'InformationTechnology1_2_1',
#   'Day_2',
#   0,
#   4),
#  ('SpreadEventsConstraint_InformationTechnology1_2_1',
#   'InformationTechnology1_2_1',
#   'Day_3',
#   2,
#   4),
#  ('SpreadEventsConstraint_InformationTechnology1_2_1',
#   'InformationTechnology1_2_1',
#   'Day_4',
#   2,
#   2),
#  ('SpreadEventsConstraint_HumanBehavior2_0_1',
#   'HumanBehavior2_0_1',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_HumanBehavior2_0_1',
#   'HumanBehavior2_0_1',
#   'Day_1',
#   0,
#   1),
#  ('SpreadEventsConstraint_HumanBehavior2_0_1',
#   'HumanBehavior2_0_1',
#   'Day_2',
#   0,
#   2),
#  ('SpreadEventsConstraint_HumanBehavior2_0_1',
#   'HumanBehavior2_0_1',
#   'Day_3',
#   0,
#   1),
#  ('SpreadEventsConstraint_HumanBehavior2_0_1',
#   'HumanBehavior2_0_1',
#   'Day_4',
#   0,
#   1),
#  ('SpreadEventsConstraint_Spanish3_3_1', 'Spanish3_3_1', 'Day_0', 0, 0),
#  ('SpreadEventsConstraint_Spanish3_3_1', 'Spanish3_3_1', 'Day_1', 2, 2),
#  ('SpreadEventsConstraint_Spanish3_3_1', 'Spanish3_3_1', 'Day_2', 2, 4),
#  ('SpreadEventsConstraint_Spanish3_3_1', 'Spanish3_3_1', 'Day_3', 0, 2),
#  ('SpreadEventsConstraint_Spanish3_3_1', 'Spanish3_3_1', 'Day_4', 4, 4),
#  ('SpreadEventsConstraint_WorldHistorySem2_4_2',
#   'WorldHistorySem2_4_2',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_WorldHistorySem2_4_2',
#   'WorldHistorySem2_4_2',
#   'Day_1',
#   0,
#   5),
#  ('SpreadEventsConstraint_WorldHistorySem2_4_2',
#   'WorldHistorySem2_4_2',
#   'Day_2',
#   0,
#   10),
#  ('SpreadEventsConstraint_WorldHistorySem2_4_2',
#   'WorldHistorySem2_4_2',
#   'Day_3',
#   0,
#   10),
#  ('SpreadEventsConstraint_WorldHistorySem2_4_2',
#   'WorldHistorySem2_4_2',
#   'Day_4',
#   0,
#   5),
#  ('SpreadEventsConstraint_HealthSciences-Advanced_1_2',
#   'HealthSciences-Advanced_1_2',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_HealthSciences-Advanced_1_2',
#   'HealthSciences-Advanced_1_2',
#   'Day_1',
#   0,
#   1),
#  ('SpreadEventsConstraint_HealthSciences-Advanced_1_2',
#   'HealthSciences-Advanced_1_2',
#   'Day_2',
#   0,
#   1),
#  ('SpreadEventsConstraint_HealthSciences-Advanced_1_2',
#   'HealthSciences-Advanced_1_2',
#   'Day_3',
#   0,
#   1),
#  ('SpreadEventsConstraint_HealthSciences-Advanced_1_2',
#   'HealthSciences-Advanced_1_2',
#   'Day_4',
#   1,
#   2),
#  ('SpreadEventsConstraint_CompositionAP_5_3',
#   'CompositionAP_5_3',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_CompositionAP_5_3',
#   'CompositionAP_5_3',
#   'Day_1',
#   0,
#   2),
#  ('SpreadEventsConstraint_CompositionAP_5_3',
#   'CompositionAP_5_3',
#   'Day_2',
#   0,
#   4),
#  ('SpreadEventsConstraint_CompositionAP_5_3',
#   'CompositionAP_5_3',
#   'Day_3',
#   0,
#   4),
#  ('SpreadEventsConstraint_CompositionAP_5_3',
#   'CompositionAP_5_3',
#   'Day_4',
#   0,
#   4),
#  ('SpreadEventsConstraint_Sociology_2_2', 'Sociology_2_2', 'Day_0', 0, 0),
#  ('SpreadEventsConstraint_Sociology_2_2', 'Sociology_2_2', 'Day_1', 0, 2),
#  ('SpreadEventsConstraint_Sociology_2_2', 'Sociology_2_2', 'Day_2', 0, 2),
#  ('SpreadEventsConstraint_Sociology_2_2', 'Sociology_2_2', 'Day_3', 0, 2),
#  ('SpreadEventsConstraint_Sociology_2_2', 'Sociology_2_2', 'Day_4', 2, 2),
#  ('SpreadEventsConstraint_GeometrySem2_3_1',
#   'GeometrySem2_3_1',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_GeometrySem2_3_1',
#   'GeometrySem2_3_1',
#   'Day_1',
#   1,
#   1),
#  ('SpreadEventsConstraint_GeometrySem2_3_1',
#   'GeometrySem2_3_1',
#   'Day_2',
#   1,
#   1),
#  ('SpreadEventsConstraint_GeometrySem2_3_1',
#   'GeometrySem2_3_1',
#   'Day_3',
#   1,
#   2),
#  ('SpreadEventsConstraint_GeometrySem2_3_1',
#   'GeometrySem2_3_1',
#   'Day_4',
#   1,
#   2),
#  ('SpreadEventsConstraint_AdvancedAlgebra(H)Sem2_1_2',
#   'AdvancedAlgebra(H)Sem2_1_2',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_AdvancedAlgebra(H)Sem2_1_2',
#   'AdvancedAlgebra(H)Sem2_1_2',
#   'Day_1',
#   0,
#   3),
#  ('SpreadEventsConstraint_AdvancedAlgebra(H)Sem2_1_2',
#   'AdvancedAlgebra(H)Sem2_1_2',
#   'Day_2',
#   0,
#   6),
#  ('SpreadEventsConstraint_AdvancedAlgebra(H)Sem2_1_2',
#   'AdvancedAlgebra(H)Sem2_1_2',
#   'Day_3',
#   0,
#   6),
#  ('SpreadEventsConstraint_AdvancedAlgebra(H)Sem2_1_2',
#   'AdvancedAlgebra(H)Sem2_1_2',
#   'Day_4',
#   3,
#   9),
#  ('SpreadEventsConstraint_SpeechPathologyA_0_1',
#   'SpeechPathologyA_0_1',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_SpeechPathologyA_0_1',
#   'SpeechPathologyA_0_1',
#   'Day_1',
#   0,
#   1),
#  ('SpreadEventsConstraint_SpeechPathologyA_0_1',
#   'SpeechPathologyA_0_1',
#   'Day_2',
#   0,
#   2),
#  ('SpreadEventsConstraint_SpeechPathologyA_0_1',
#   'SpeechPathologyA_0_1',
#   'Day_3',
#   0,
#   2),
#  ('SpreadEventsConstraint_SpeechPathologyA_0_1',
#   'SpeechPathologyA_0_1',
#   'Day_4',
#   0,
#   1),
#  ('SpreadEventsConstraint_Pre-Calculus(H)_0_2',
#   'Pre-Calculus(H)_0_2',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_Pre-Calculus(H)_0_2',
#   'Pre-Calculus(H)_0_2',
#   'Day_1',
#   3,
#   3),
#  ('SpreadEventsConstraint_Pre-Calculus(H)_0_2',
#   'Pre-Calculus(H)_0_2',
#   'Day_2',
#   3,
#   3),
#  ('SpreadEventsConstraint_Pre-Calculus(H)_0_2',
#   'Pre-Calculus(H)_0_2',
#   'Day_3',
#   3,
#   3),
#  ('SpreadEventsConstraint_Pre-Calculus(H)_0_2',
#   'Pre-Calculus(H)_0_2',
#   'Day_4',
#   3,
#   3),
#  ('SpreadEventsConstraint_Algebra1Sem2_0_1',
#   'Algebra1Sem2_0_1',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_Algebra1Sem2_0_1',
#   'Algebra1Sem2_0_1',
#   'Day_1',
#   2,
#   4),
#  ('SpreadEventsConstraint_Algebra1Sem2_0_1',
#   'Algebra1Sem2_0_1',
#   'Day_2',
#   0,
#   4),
#  ('SpreadEventsConstraint_Algebra1Sem2_0_1',
#   'Algebra1Sem2_0_1',
#   'Day_3',
#   2,
#   4),
#  ('SpreadEventsConstraint_Algebra1Sem2_0_1',
#   'Algebra1Sem2_0_1',
#   'Day_4',
#   2,
#   2),
#  ('SpreadEventsConstraint_Architecture1_0_1',
#   'Architecture1_0_1',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_Architecture1_0_1',
#   'Architecture1_0_1',
#   'Day_1',
#   2,
#   4),
#  ('SpreadEventsConstraint_Architecture1_0_1',
#   'Architecture1_0_1',
#   'Day_2',
#   0,
#   2),
#  ('SpreadEventsConstraint_Architecture1_0_1',
#   'Architecture1_0_1',
#   'Day_3',
#   2,
#   2),
#  ('SpreadEventsConstraint_Architecture1_0_1',
#   'Architecture1_0_1',
#   'Day_4',
#   4,
#   4),
#  ('SpreadEventsConstraint_Math-Vocational_0_1',
#   'Math-Vocational_0_1',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_Math-Vocational_0_1',
#   'Math-Vocational_0_1',
#   'Day_1',
#   1,
#   2),
#  ('SpreadEventsConstraint_Math-Vocational_0_1',
#   'Math-Vocational_0_1',
#   'Day_2',
#   0,
#   1),
#  ('SpreadEventsConstraint_Math-Vocational_0_1',
#   'Math-Vocational_0_1',
#   'Day_3',
#   1,
#   2),
#  ('SpreadEventsConstraint_Math-Vocational_0_1',
#   'Math-Vocational_0_1',
#   'Day_4',
#   1,
#   2),
#  ('SpreadEventsConstraint_English9_4_1', 'English9_4_1', 'Day_0', 0, 0),
#  ('SpreadEventsConstraint_English9_4_1', 'English9_4_1', 'Day_1', 4, 4),
#  ('SpreadEventsConstraint_English9_4_1', 'English9_4_1', 'Day_2', 4, 4),
#  ('SpreadEventsConstraint_English9_4_1', 'English9_4_1', 'Day_3', 0, 4),
#  ('SpreadEventsConstraint_English9_4_1', 'English9_4_1', 'Day_4', 0, 4),
#  ('SpreadEventsConstraint_UnitedStatesHistoryAPSem2_2_2',
#   'UnitedStatesHistoryAPSem2_2_2',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_UnitedStatesHistoryAPSem2_2_2',
#   'UnitedStatesHistoryAPSem2_2_2',
#   'Day_1',
#   0,
#   4),
#  ('SpreadEventsConstraint_UnitedStatesHistoryAPSem2_2_2',
#   'UnitedStatesHistoryAPSem2_2_2',
#   'Day_2',
#   0,
#   8),
#  ('SpreadEventsConstraint_UnitedStatesHistoryAPSem2_2_2',
#   'UnitedStatesHistoryAPSem2_2_2',
#   'Day_3',
#   0,
#   4),
#  ('SpreadEventsConstraint_UnitedStatesHistoryAPSem2_2_2',
#   'UnitedStatesHistoryAPSem2_2_2',
#   'Day_4',
#   4,
#   8),
#  ('SpreadEventsConstraint_English9_2_1', 'English9_2_1', 'Day_0', 0, 0),
#  ('SpreadEventsConstraint_English9_2_1', 'English9_2_1', 'Day_1', 4, 4),
#  ('SpreadEventsConstraint_English9_2_1', 'English9_2_1', 'Day_2', 0, 4),
#  ('SpreadEventsConstraint_English9_2_1', 'English9_2_1', 'Day_3', 0, 8),
#  ('SpreadEventsConstraint_English9_2_1', 'English9_2_1', 'Day_4', 0, 4),
#  ('SpreadEventsConstraint_Spanish5AP_0_1', 'Spanish5AP_0_1', 'Day_0', 0, 0),
#  ('SpreadEventsConstraint_Spanish5AP_0_1', 'Spanish5AP_0_1', 'Day_1', 3, 3),
#  ('SpreadEventsConstraint_Spanish5AP_0_1', 'Spanish5AP_0_1', 'Day_2', 3, 3),
#  ('SpreadEventsConstraint_Spanish5AP_0_1', 'Spanish5AP_0_1', 'Day_3', 3, 3),
#  ('SpreadEventsConstraint_Spanish5AP_0_1', 'Spanish5AP_0_1', 'Day_4', 3, 3),
#  ('SpreadEventsConstraint_Literature2_3_1', 'Literature2_3_1', 'Day_0', 0, 0),
#  ('SpreadEventsConstraint_Literature2_3_1', 'Literature2_3_1', 'Day_1', 1, 1),
#  ('SpreadEventsConstraint_Literature2_3_1', 'Literature2_3_1', 'Day_2', 0, 1),
#  ('SpreadEventsConstraint_Literature2_3_1', 'Literature2_3_1', 'Day_3', 0, 2),
#  ('SpreadEventsConstraint_Literature2_3_1', 'Literature2_3_1', 'Day_4', 0, 1),
#  ('SpreadEventsConstraint_Choir-Concert_0_1',
#   'Choir-Concert_0_1',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_Choir-Concert_0_1',
#   'Choir-Concert_0_1',
#   'Day_1',
#   1,
#   1),
#  ('SpreadEventsConstraint_Choir-Concert_0_1',
#   'Choir-Concert_0_1',
#   'Day_2',
#   1,
#   2),
#  ('SpreadEventsConstraint_Choir-Concert_0_1',
#   'Choir-Concert_0_1',
#   'Day_3',
#   0,
#   1),
#  ('SpreadEventsConstraint_Choir-Concert_0_1',
#   'Choir-Concert_0_1',
#   'Day_4',
#   2,
#   2),
#  ('SpreadEventsConstraint_Civics_1_2', 'Civics_1_2', 'Day_0', 0, 0),
#  ('SpreadEventsConstraint_Civics_1_2', 'Civics_1_2', 'Day_1', 0, 6),
#  ('SpreadEventsConstraint_Civics_1_2', 'Civics_1_2', 'Day_2', 0, 12),
#  ('SpreadEventsConstraint_Civics_1_2', 'Civics_1_2', 'Day_3', 0, 18),
#  ('SpreadEventsConstraint_Civics_1_2', 'Civics_1_2', 'Day_4', 0, 18),
#  ('SpreadEventsConstraint_German4(H)_0_1', 'German4(H)_0_1', 'Day_0', 0, 0),
#  ('SpreadEventsConstraint_German4(H)_0_1', 'German4(H)_0_1', 'Day_1', 1, 1),
#  ('SpreadEventsConstraint_German4(H)_0_1', 'German4(H)_0_1', 'Day_2', 1, 1),
#  ('SpreadEventsConstraint_German4(H)_0_1', 'German4(H)_0_1', 'Day_3', 1, 1),
#  ('SpreadEventsConstraint_German4(H)_0_1', 'German4(H)_0_1', 'Day_4', 1, 1),
#  ('SpreadEventsConstraint_Latin4AP_0_1', 'Latin4AP_0_1', 'Day_0', 0, 0),
#  ('SpreadEventsConstraint_Latin4AP_0_1', 'Latin4AP_0_1', 'Day_1', 1, 1),
#  ('SpreadEventsConstraint_Latin4AP_0_1', 'Latin4AP_0_1', 'Day_2', 1, 1),
#  ('SpreadEventsConstraint_Latin4AP_0_1', 'Latin4AP_0_1', 'Day_3', 1, 1),
#  ('SpreadEventsConstraint_Latin4AP_0_1', 'Latin4AP_0_1', 'Day_4', 1, 1),
#  ('SpreadEventsConstraint_Band-Grade9_0_1', 'Band-Grade9_0_1', 'Day_0', 0, 0),
#  ('SpreadEventsConstraint_Band-Grade9_0_1', 'Band-Grade9_0_1', 'Day_1', 1, 2),
#  ('SpreadEventsConstraint_Band-Grade9_0_1', 'Band-Grade9_0_1', 'Day_2', 1, 2),
#  ('SpreadEventsConstraint_Band-Grade9_0_1', 'Band-Grade9_0_1', 'Day_3', 1, 1),
#  ('SpreadEventsConstraint_Band-Grade9_0_1', 'Band-Grade9_0_1', 'Day_4', 1, 1),
#  ('SpreadEventsConstraint_Spanish1_1_1', 'Spanish1_1_1', 'Day_0', 0, 0),
#  ('SpreadEventsConstraint_Spanish1_1_1', 'Spanish1_1_1', 'Day_1', 2, 4),
#  ('SpreadEventsConstraint_Spanish1_1_1', 'Spanish1_1_1', 'Day_2', 0, 4),
#  ('SpreadEventsConstraint_Spanish1_1_1', 'Spanish1_1_1', 'Day_3', 2, 4),
#  ('SpreadEventsConstraint_Spanish1_1_1', 'Spanish1_1_1', 'Day_4', 2, 2),
#  ('SpreadEventsConstraint_BroadcastTelevision_0_2',
#   'BroadcastTelevision_0_2',
#   'Day_0',
#   0,
#   1),
#  ('SpreadEventsConstraint_BroadcastTelevision_0_2',
#   'BroadcastTelevision_0_2',
#   'Day_1',
#   0,
#   1),
#  ('SpreadEventsConstraint_BroadcastTelevision_0_2',
#   'BroadcastTelevision_0_2',
#   'Day_2',
#   0,
#   2),
#  ('SpreadEventsConstraint_BroadcastTelevision_0_2',
#   'BroadcastTelevision_0_2',
#   'Day_3',
#   0,
#   2),
#  ('SpreadEventsConstraint_BroadcastTelevision_0_2',
#   'BroadcastTelevision_0_2',
#   'Day_4',
#   0,
#   1),
#  ('SpreadEventsConstraint_CurrentEvents_1_1',
#   'CurrentEvents_1_1',
# ...
#   'AdvancedAlgebra(H)Sem2_0_2',
#   'Day_3',
#   3,
#   3),
#  ('SpreadEventsConstraint_AdvancedAlgebra(H)Sem2_0_2',
#   'AdvancedAlgebra(H)Sem2_0_2',
#   'Day_4',
#   3,
#   3),
#  ('SpreadEventsConstraint_Architecture2_0_2',
#   'Architecture2_0_2',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_Architecture2_0_2',
#   'Architecture2_0_2',
#   'Day_1',
#   0,
#   1),
#  ('SpreadEventsConstraint_Architecture2_0_2',
#   'Architecture2_0_2',
#   'Day_2',
#   0,
#   2),
#  ('SpreadEventsConstraint_Architecture2_0_2',
#   'Architecture2_0_2',
#   'Day_3',
#   0,
#   1),
#  ('SpreadEventsConstraint_Architecture2_0_2',
#   'Architecture2_0_2',
#   'Day_4',
#   1,
#   1),
#  ('SpreadEventsConstraint_Algebra1(S1)-YearCourse_1_1',
#   'Algebra1(S1)-YearCourse_1_1',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_Algebra1(S1)-YearCourse_1_1',
#   'Algebra1(S1)-YearCourse_1_1',
#   'Day_1',
#   3,
#   3),
#  ('SpreadEventsConstraint_Algebra1(S1)-YearCourse_1_1',
#   'Algebra1(S1)-YearCourse_1_1',
#   'Day_2',
#   3,
#   6),
#  ('SpreadEventsConstraint_Algebra1(S1)-YearCourse_1_1',
#   'Algebra1(S1)-YearCourse_1_1',
#   'Day_3',
#   0,
#   6),
#  ('SpreadEventsConstraint_Algebra1(S1)-YearCourse_1_1',
#   'Algebra1(S1)-YearCourse_1_1',
#   'Day_4',
#   3,
#   6),
#  ('SpreadEventsConstraint_Accounting-Begining_0_1',
#   'Accounting-Begining_0_1',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_Accounting-Begining_0_1',
#   'Accounting-Begining_0_1',
#   'Day_1',
#   2,
#   4),
#  ('SpreadEventsConstraint_Accounting-Begining_0_1',
#   'Accounting-Begining_0_1',
#   'Day_2',
#   0,
#   4),
#  ('SpreadEventsConstraint_Accounting-Begining_0_1',
#   'Accounting-Begining_0_1',
#   'Day_3',
#   0,
#   4),
#  ('SpreadEventsConstraint_Accounting-Begining_0_1',
#   'Accounting-Begining_0_1',
#   'Day_4',
#   2,
#   4),
#  ('SpreadEventsConstraint_Humanities_3_2', 'Humanities_3_2', 'Day_0', 0, 0),
#  ('SpreadEventsConstraint_Humanities_3_2', 'Humanities_3_2', 'Day_1', 0, 0),
#  ('SpreadEventsConstraint_Humanities_3_2', 'Humanities_3_2', 'Day_2', 6, 6),
#  ('SpreadEventsConstraint_Humanities_3_2', 'Humanities_3_2', 'Day_3', 0, 0),
#  ('SpreadEventsConstraint_Humanities_3_2', 'Humanities_3_2', 'Day_4', 0, 0),
#  ('SpreadEventsConstraint_Debate_0_1', 'Debate_0_1', 'Day_0', 0, 0),
#  ('SpreadEventsConstraint_Debate_0_1', 'Debate_0_1', 'Day_1', 0, 1),
#  ('SpreadEventsConstraint_Debate_0_1', 'Debate_0_1', 'Day_2', 0, 2),
#  ('SpreadEventsConstraint_Debate_0_1', 'Debate_0_1', 'Day_3', 0, 2),
#  ('SpreadEventsConstraint_Debate_0_1', 'Debate_0_1', 'Day_4', 0, 1),
#  ('SpreadEventsConstraint_Pre-Calculus_1_2',
#   'Pre-Calculus_1_2',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_Pre-Calculus_1_2',
#   'Pre-Calculus_1_2',
#   'Day_1',
#   3,
#   3),
#  ('SpreadEventsConstraint_Pre-Calculus_1_2',
#   'Pre-Calculus_1_2',
#   'Day_2',
#   3,
#   3),
#  ('SpreadEventsConstraint_Pre-Calculus_1_2',
#   'Pre-Calculus_1_2',
#   'Day_3',
#   3,
#   3),
#  ('SpreadEventsConstraint_Pre-Calculus_1_2',
#   'Pre-Calculus_1_2',
#   'Day_4',
#   3,
#   3),
#  ('SpreadEventsConstraint_Swimming2_0_1', 'Swimming2_0_1', 'Day_0', 0, 0),
#  ('SpreadEventsConstraint_Swimming2_0_1', 'Swimming2_0_1', 'Day_1', 3, 3),
#  ('SpreadEventsConstraint_Swimming2_0_1', 'Swimming2_0_1', 'Day_2', 0, 3),
#  ('SpreadEventsConstraint_Swimming2_0_1', 'Swimming2_0_1', 'Day_3', 0, 3),
#  ('SpreadEventsConstraint_Swimming2_0_1', 'Swimming2_0_1', 'Day_4', 0, 3),
#  ('SpreadEventsConstraint_GlobalIntolerance_0_2',
#   'GlobalIntolerance_0_2',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_GlobalIntolerance_0_2',
#   'GlobalIntolerance_0_2',
#   'Day_1',
#   0,
#   4),
#  ('SpreadEventsConstraint_GlobalIntolerance_0_2',
#   'GlobalIntolerance_0_2',
#   'Day_2',
#   0,
#   8),
#  ('SpreadEventsConstraint_GlobalIntolerance_0_2',
#   'GlobalIntolerance_0_2',
#   'Day_3',
#   0,
#   8),
#  ('SpreadEventsConstraint_GlobalIntolerance_0_2',
#   'GlobalIntolerance_0_2',
#   'Day_4',
#   0,
#   4),
#  ('SpreadEventsConstraint_WorldHistory(H)Sem2_1_2',
#   'WorldHistory(H)Sem2_1_2',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_WorldHistory(H)Sem2_1_2',
#   'WorldHistory(H)Sem2_1_2',
#   'Day_1',
#   0,
#   5),
#  ('SpreadEventsConstraint_WorldHistory(H)Sem2_1_2',
#   'WorldHistory(H)Sem2_1_2',
#   'Day_2',
#   0,
#   10),
#  ('SpreadEventsConstraint_WorldHistory(H)Sem2_1_2',
#   'WorldHistory(H)Sem2_1_2',
#   'Day_3',
#   0,
#   10),
#  ('SpreadEventsConstraint_WorldHistory(H)Sem2_1_2',
#   'WorldHistory(H)Sem2_1_2',
#   'Day_4',
#   0,
#   5),
#  ('SpreadEventsConstraint_CalculusABAP_1_2',
#   'CalculusABAP_1_2',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_CalculusABAP_1_2',
#   'CalculusABAP_1_2',
#   'Day_1',
#   2,
#   2),
#  ('SpreadEventsConstraint_CalculusABAP_1_2',
#   'CalculusABAP_1_2',
#   'Day_2',
#   2,
#   2),
#  ('SpreadEventsConstraint_CalculusABAP_1_2',
#   'CalculusABAP_1_2',
#   'Day_3',
#   2,
#   2),
#  ('SpreadEventsConstraint_CalculusABAP_1_2',
#   'CalculusABAP_1_2',
#   'Day_4',
#   2,
#   2),
#  ('SpreadEventsConstraint_Sociology_1_2', 'Sociology_1_2', 'Day_0', 0, 0),
#  ('SpreadEventsConstraint_Sociology_1_2', 'Sociology_1_2', 'Day_1', 0, 2),
#  ('SpreadEventsConstraint_Sociology_1_2', 'Sociology_1_2', 'Day_2', 0, 4),
#  ('SpreadEventsConstraint_Sociology_1_2', 'Sociology_1_2', 'Day_3', 0, 4),
#  ('SpreadEventsConstraint_Sociology_1_2', 'Sociology_1_2', 'Day_4', 0, 2),
#  ('SpreadEventsConstraint_Theater4_0_1', 'Theater4_0_1', 'Day_0', 0, 0),
#  ('SpreadEventsConstraint_Theater4_0_1', 'Theater4_0_1', 'Day_1', 1, 1),
#  ('SpreadEventsConstraint_Theater4_0_1', 'Theater4_0_1', 'Day_2', 1, 1),
#  ('SpreadEventsConstraint_Theater4_0_1', 'Theater4_0_1', 'Day_3', 1, 1),
#  ('SpreadEventsConstraint_Theater4_0_1', 'Theater4_0_1', 'Day_4', 1, 1),
#  ('SpreadEventsConstraint_SpeechPathologyC_0_1',
#   'SpeechPathologyC_0_1',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_SpeechPathologyC_0_1',
#   'SpeechPathologyC_0_1',
#   'Day_1',
#   0,
#   1),
#  ('SpreadEventsConstraint_SpeechPathologyC_0_1',
#   'SpeechPathologyC_0_1',
#   'Day_2',
#   0,
#   2),
#  ('SpreadEventsConstraint_SpeechPathologyC_0_1',
#   'SpeechPathologyC_0_1',
#   'Day_3',
#   0,
#   2),
#  ('SpreadEventsConstraint_SpeechPathologyC_0_1',
#   'SpeechPathologyC_0_1',
#   'Day_4',
#   0,
#   1),
#  ('SpreadEventsConstraint_Spanish4(H)_0_1', 'Spanish4(H)_0_1', 'Day_0', 0, 0),
#  ('SpreadEventsConstraint_Spanish4(H)_0_1', 'Spanish4(H)_0_1', 'Day_1', 3, 6),
#  ('SpreadEventsConstraint_Spanish4(H)_0_1', 'Spanish4(H)_0_1', 'Day_2', 0, 6),
#  ('SpreadEventsConstraint_Spanish4(H)_0_1', 'Spanish4(H)_0_1', 'Day_3', 0, 6),
#  ('SpreadEventsConstraint_Spanish4(H)_0_1', 'Spanish4(H)_0_1', 'Day_4', 3, 6),
#  ('SpreadEventsConstraint_GeometrySem2_0_1',
#   'GeometrySem2_0_1',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_GeometrySem2_0_1',
#   'GeometrySem2_0_1',
#   'Day_1',
#   3,
#   6),
#  ('SpreadEventsConstraint_GeometrySem2_0_1',
#   'GeometrySem2_0_1',
#   'Day_2',
#   0,
#   6),
#  ('SpreadEventsConstraint_GeometrySem2_0_1',
#   'GeometrySem2_0_1',
#   'Day_3',
#   0,
#   6),
#  ('SpreadEventsConstraint_GeometrySem2_0_1',
#   'GeometrySem2_0_1',
#   'Day_4',
#   3,
#   6),
#  ('SpreadEventsConstraint_CalculusABAP_0_2',
#   'CalculusABAP_0_2',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_CalculusABAP_0_2',
#   'CalculusABAP_0_2',
#   'Day_1',
#   0,
#   2),
#  ('SpreadEventsConstraint_CalculusABAP_0_2',
#   'CalculusABAP_0_2',
#   'Day_2',
#   2,
#   4),
#  ('SpreadEventsConstraint_CalculusABAP_0_2',
#   'CalculusABAP_0_2',
#   'Day_3',
#   2,
#   2),
#  ('SpreadEventsConstraint_CalculusABAP_0_2',
#   'CalculusABAP_0_2',
#   'Day_4',
#   2,
#   2),
#  ('SpreadEventsConstraint_Humanities_0_2', 'Humanities_0_2', 'Day_0', 0, 0),
#  ('SpreadEventsConstraint_Humanities_0_2', 'Humanities_0_2', 'Day_1', 0, 3),
#  ('SpreadEventsConstraint_Humanities_0_2', 'Humanities_0_2', 'Day_2', 0, 6),
#  ('SpreadEventsConstraint_Humanities_0_2', 'Humanities_0_2', 'Day_3', 0, 6),
#  ('SpreadEventsConstraint_Humanities_0_2', 'Humanities_0_2', 'Day_4', 0, 3),
#  ('SpreadEventsConstraint_Spanish1_3_1', 'Spanish1_3_1', 'Day_0', 0, 0),
#  ('SpreadEventsConstraint_Spanish1_3_1', 'Spanish1_3_1', 'Day_1', 3, 6),
#  ('SpreadEventsConstraint_Spanish1_3_1', 'Spanish1_3_1', 'Day_2', 0, 6),
#  ('SpreadEventsConstraint_Spanish1_3_1', 'Spanish1_3_1', 'Day_3', 0, 6),
#  ('SpreadEventsConstraint_Spanish1_3_1', 'Spanish1_3_1', 'Day_4', 3, 6),
#  ('SpreadEventsConstraint_Spanish5(H)_0_1', 'Spanish5(H)_0_1', 'Day_0', 0, 0),
#  ('SpreadEventsConstraint_Spanish5(H)_0_1', 'Spanish5(H)_0_1', 'Day_1', 0, 3),
#  ('SpreadEventsConstraint_Spanish5(H)_0_1', 'Spanish5(H)_0_1', 'Day_2', 0, 6),
#  ('SpreadEventsConstraint_Spanish5(H)_0_1', 'Spanish5(H)_0_1', 'Day_3', 0, 6),
#  ('SpreadEventsConstraint_Spanish5(H)_0_1', 'Spanish5(H)_0_1', 'Day_4', 0, 3),
#  ('SpreadEventsConstraint_PsychologyAP_0_1',
#   'PsychologyAP_0_1',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_PsychologyAP_0_1',
#   'PsychologyAP_0_1',
#   'Day_1',
#   0,
#   2),
#  ('SpreadEventsConstraint_PsychologyAP_0_1',
#   'PsychologyAP_0_1',
#   'Day_2',
#   0,
#   2),
#  ('SpreadEventsConstraint_PsychologyAP_0_1',
#   'PsychologyAP_0_1',
#   'Day_3',
#   0,
#   2),
#  ('SpreadEventsConstraint_PsychologyAP_0_1',
#   'PsychologyAP_0_1',
#   'Day_4',
#   4,
#   4),
#  ('SpreadEventsConstraint_MediaConvergence_0_1',
#   'MediaConvergence_0_1',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_MediaConvergence_0_1',
#   'MediaConvergence_0_1',
#   'Day_1',
#   1,
#   2),
#  ('SpreadEventsConstraint_MediaConvergence_0_1',
#   'MediaConvergence_0_1',
#   'Day_2',
#   0,
#   1),
#  ('SpreadEventsConstraint_MediaConvergence_0_1',
#   'MediaConvergence_0_1',
#   'Day_3',
#   1,
#   2),
#  ('SpreadEventsConstraint_MediaConvergence_0_1',
#   'MediaConvergence_0_1',
#   'Day_4',
#   1,
#   2),
#  ('SpreadEventsConstraint_T.V.Production1_0_2',
#   'T.V.Production1_0_2',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_T.V.Production1_0_2',
#   'T.V.Production1_0_2',
#   'Day_1',
#   2,
#   2),
#  ('SpreadEventsConstraint_T.V.Production1_0_2',
#   'T.V.Production1_0_2',
#   'Day_2',
#   2,
#   2),
#  ('SpreadEventsConstraint_T.V.Production1_0_2',
#   'T.V.Production1_0_2',
#   'Day_3',
#   2,
#   2),
#  ('SpreadEventsConstraint_T.V.Production1_0_2',
#   'T.V.Production1_0_2',
#   'Day_4',
#   2,
#   2),
#  ('SpreadEventsConstraint_ELL1-A_0_1', 'ELL1-A_0_1', 'Day_0', 0, 0),
#  ('SpreadEventsConstraint_ELL1-A_0_1', 'ELL1-A_0_1', 'Day_1', 1, 2),
#  ('SpreadEventsConstraint_ELL1-A_0_1', 'ELL1-A_0_1', 'Day_2', 0, 1),
#  ('SpreadEventsConstraint_ELL1-A_0_1', 'ELL1-A_0_1', 'Day_3', 1, 1),
#  ('SpreadEventsConstraint_ELL1-A_0_1', 'ELL1-A_0_1', 'Day_4', 2, 2),
#  ('SpreadEventsConstraint_UnitedStatesHistoryAPSem2_1_2',
#   'UnitedStatesHistoryAPSem2_1_2',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_UnitedStatesHistoryAPSem2_1_2',
#   'UnitedStatesHistoryAPSem2_1_2',
#   'Day_1',
#   0,
#   4),
#  ('SpreadEventsConstraint_UnitedStatesHistoryAPSem2_1_2',
#   'UnitedStatesHistoryAPSem2_1_2',
#   'Day_2',
#   0,
#   8),
#  ('SpreadEventsConstraint_UnitedStatesHistoryAPSem2_1_2',
#   'UnitedStatesHistoryAPSem2_1_2',
#   'Day_3',
#   0,
#   8),
#  ('SpreadEventsConstraint_UnitedStatesHistoryAPSem2_1_2',
#   'UnitedStatesHistoryAPSem2_1_2',
#   'Day_4',
#   4,
#   12),
#  ('SpreadEventsConstraint_ComputerAidedDesign_0_1',
#   'ComputerAidedDesign_0_1',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_ComputerAidedDesign_0_1',
#   'ComputerAidedDesign_0_1',
#   'Day_1',
#   1,
#   1),
#  ('SpreadEventsConstraint_ComputerAidedDesign_0_1',
#   'ComputerAidedDesign_0_1',
#   'Day_2',
#   0,
#   1),
#  ('SpreadEventsConstraint_ComputerAidedDesign_0_1',
#   'ComputerAidedDesign_0_1',
#   'Day_3',
#   0,
#   1),
#  ('SpreadEventsConstraint_ComputerAidedDesign_0_1',
#   'ComputerAidedDesign_0_1',
#   'Day_4',
#   0,
#   1),
#  ('SpreadEventsConstraint_HumanBehavior1_0_2',
#   'HumanBehavior1_0_2',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_HumanBehavior1_0_2',
#   'HumanBehavior1_0_2',
#   'Day_1',
#   0,
#   3),
#  ('SpreadEventsConstraint_HumanBehavior1_0_2',
#   'HumanBehavior1_0_2',
#   'Day_2',
#   0,
#   6),
#  ('SpreadEventsConstraint_HumanBehavior1_0_2',
#   'HumanBehavior1_0_2',
#   'Day_3',
#   0,
#   6),
#  ('SpreadEventsConstraint_HumanBehavior1_0_2',
#   'HumanBehavior1_0_2',
#   'Day_4',
#   0,
#   3),
#  ('SpreadEventsConstraint_InformationTechnology1_1_1',
#   'InformationTechnology1_1_1',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_InformationTechnology1_1_1',
#   'InformationTechnology1_1_1',
#   'Day_1',
#   2,
#   4),
#  ('SpreadEventsConstraint_InformationTechnology1_1_1',
#   'InformationTechnology1_1_1',
#   'Day_2',
#   0,
#   4),
#  ('SpreadEventsConstraint_InformationTechnology1_1_1',
#   'InformationTechnology1_1_1',
#   'Day_3',
#   2,
#   4),
#  ('SpreadEventsConstraint_InformationTechnology1_1_1',
#   'InformationTechnology1_1_1',
#   'Day_4',
#   2,
#   2),
#  ('SpreadEventsConstraint_EarthSpaceScience_0_2',
#   'EarthSpaceScience_0_2',
#   'Day_0',
#   0,
#   12),
#  ('SpreadEventsConstraint_EarthSpaceScience_0_2',
#   'EarthSpaceScience_0_2',
#   'Day_1',
#   0,
#   12),
#  ('SpreadEventsConstraint_EarthSpaceScience_0_2',
#   'EarthSpaceScience_0_2',
#   'Day_2',
#   0,
#   18),
#  ('SpreadEventsConstraint_EarthSpaceScience_0_2',
#   'EarthSpaceScience_0_2',
#   'Day_3',
#   0,
#   6),
#  ('SpreadEventsConstraint_EarthSpaceScience_0_2',
#   'EarthSpaceScience_0_2',
#   'Day_4',
#   0,
#   6),
#  ('SpreadEventsConstraint_Civics_0_2', 'Civics_0_2', 'Day_0', 0, 0),
#  ('SpreadEventsConstraint_Civics_0_2', 'Civics_0_2', 'Day_1', 0, 3),
#  ('SpreadEventsConstraint_Civics_0_2', 'Civics_0_2', 'Day_2', 3, 6),
#  ('SpreadEventsConstraint_Civics_0_2', 'Civics_0_2', 'Day_3', 0, 3),
#  ('SpreadEventsConstraint_Civics_0_2', 'Civics_0_2', 'Day_4', 0, 3),
#  ('SpreadEventsConstraint_WorldHistory(H)Sem2_3_2',
#   'WorldHistory(H)Sem2_3_2',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_WorldHistory(H)Sem2_3_2',
#   'WorldHistory(H)Sem2_3_2',
#   'Day_1',
#   0,
#   1),
#  ('SpreadEventsConstraint_WorldHistory(H)Sem2_3_2',
#   'WorldHistory(H)Sem2_3_2',
#   'Day_2',
#   0,
#   2),
#  ('SpreadEventsConstraint_WorldHistory(H)Sem2_3_2',
#   'WorldHistory(H)Sem2_3_2',
#   'Day_3',
#   0,
#   2),
#  ('SpreadEventsConstraint_WorldHistory(H)Sem2_3_2',
#   'WorldHistory(H)Sem2_3_2',
#   'Day_4',
#   0,
#   1),
#  ('SpreadEventsConstraint_Spanish1_2_1', 'Spanish1_2_1', 'Day_0', 0, 0),
#  ('SpreadEventsConstraint_Spanish1_2_1', 'Spanish1_2_1', 'Day_1', 3, 6),
#  ('SpreadEventsConstraint_Spanish1_2_1', 'Spanish1_2_1', 'Day_2', 0, 6),
#  ('SpreadEventsConstraint_Spanish1_2_1', 'Spanish1_2_1', 'Day_3', 0, 6),
#  ('SpreadEventsConstraint_Spanish1_2_1', 'Spanish1_2_1', 'Day_4', 3, 6),
#  ('SpreadEventsConstraint_English9_1_1', 'English9_1_1', 'Day_0', 0, 0),
#  ('SpreadEventsConstraint_English9_1_1', 'English9_1_1', 'Day_1', 0, 3),
#  ('SpreadEventsConstraint_English9_1_1', 'English9_1_1', 'Day_2', 0, 6),
#  ('SpreadEventsConstraint_English9_1_1', 'English9_1_1', 'Day_3', 0, 6),
#  ('SpreadEventsConstraint_English9_1_1', 'English9_1_1', 'Day_4', 0, 3),
#  ('SpreadEventsConstraint_French3_0_1', 'French3_0_1', 'Day_0', 0, 0),
#  ('SpreadEventsConstraint_French3_0_1', 'French3_0_1', 'Day_1', 2, 4),
#  ('SpreadEventsConstraint_French3_0_1', 'French3_0_1', 'Day_2', 0, 2),
#  ('SpreadEventsConstraint_French3_0_1', 'French3_0_1', 'Day_3', 2, 4),
#  ('SpreadEventsConstraint_French3_0_1', 'French3_0_1', 'Day_4', 2, 4),
#  ('SpreadEventsConstraint_Spanish2_1_1', 'Spanish2_1_1', 'Day_0', 0, 0),
#  ('SpreadEventsConstraint_Spanish2_1_1', 'Spanish2_1_1', 'Day_1', 4, 4),
#  ('SpreadEventsConstraint_Spanish2_1_1', 'Spanish2_1_1', 'Day_2', 4, 8),
#  ('SpreadEventsConstraint_Spanish2_1_1', 'Spanish2_1_1', 'Day_3', 0, 8),
#  ('SpreadEventsConstraint_Spanish2_1_1', 'Spanish2_1_1', 'Day_4', 4, 8),
#  ('SpreadEventsConstraint_WorldHistorySem2_2_2',
#   'WorldHistorySem2_2_2',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_WorldHistorySem2_2_2',
#   'WorldHistorySem2_2_2',
#   'Day_1',
#   0,
#   5),
#  ('SpreadEventsConstraint_WorldHistorySem2_2_2',
#   'WorldHistorySem2_2_2',
#   'Day_2',
#   0,
#   10),
#  ('SpreadEventsConstraint_WorldHistorySem2_2_2',
#   'WorldHistorySem2_2_2',
#   'Day_3',
#   0,
#   10),
#  ('SpreadEventsConstraint_WorldHistorySem2_2_2',
#   'WorldHistorySem2_2_2',
#   'Day_4',
#   0,
#   5),
#  ('SpreadEventsConstraint_Choir-Freshman_0_1',
#   'Choir-Freshman_0_1',
#   'Day_0',
#   0,
#   0),
#  ('SpreadEventsConstraint_Choir-Freshman_0_1',
#   'Choir-Freshman_0_1',
#   'Day_1',
#   1,
#   2),
#  ('SpreadEventsConstraint_Choir-Freshman_0_1',
#   'Choir-Freshman_0_1',
#   'Day_2',
#   1,
#   2),
#  ('SpreadEventsConstraint_Choir-Freshman_0_1',
#   'Choir-Freshman_0_1',
#   'Day_3',
#   1,
#   1),
#  ('SpreadEventsConstraint_Choir-Freshman_0_1',
#   'Choir-Freshman_0_1',
#   'Day_4',
#   1,
#   1),
#  ...]

# %%
# Stable keys for Pyomo sets/vars
keys = [(cid, eg, tg) for cid, eg, tg, _, _ in triples]
bounds_map = {(cid, eg, tg): (mn, mx) for cid, eg, tg, mn, mx in triples}

m1.SpreadIdx = pyo.Set(initialize=keys, dimen=3)
m1.spread_under = pyo.Var(m1.SpreadIdx, domain=pyo.NonNegativeReals)
m1.spread_over = pyo.Var(m1.SpreadIdx, domain=pyo.NonNegativeReals)

def count_expr(cid, eg, tg):
    tg_times = tg_to_times.get(tg, set())
    parent_events = eg_to_events.get(eg, set())
    expr = 0.0
    for pe in parent_events: # for each parent event in constraint group
        for se in parent_to_sub.get(pe, []): #for each sub event of parent event
            for ts in feasible_starts.get(se, []): #for all feasible starts
                if ts in tg_times:
                    expr += m1.x[se, ts]
    return expr

    # under >= min - count
def under_rule(m, cid, eg, tg):
    mn, mx = bounds_map[(cid, eg, tg)]
    return m.spread_under[cid, eg, tg] >= mn - count_expr(cid, eg, tg)
m1.SpreadUnderConstr = pyo.Constraint(m1.SpreadIdx, rule=under_rule)

    # over >= count - max
def over_rule(m, cid, eg, tg):
    mn, mx = bounds_map[(cid, eg, tg)]
    return m.spread_over[cid, eg, tg] >= count_expr(cid, eg, tg) - mx
m1.SpreadOverConstr = pyo.Constraint(m1.SpreadIdx, rule=over_rule)


# weighted linear penalty
m1.SpreadEventsPenalty = pyo.Expression(
    expr=sum(
        float(cid_to_weight.get(cid, 1.0)) *
        (m1.spread_under[cid, eg, tg] + m1.spread_over[cid, eg, tg])
        for (cid, eg, tg) in m1.SpreadIdx
    )
)

# %% [markdown]
# ### Solve

# %%
# ---- Objective ---- (with soft constraints)

if hasattr(m1, "obj"):
    m1.del_component(m1.obj)

penalty_total = (m1.PreferredTimesPenalty + m1.SpreadEventsPenalty)

m1.obj = pyo.Objective(expr=penalty_total, sense=pyo.minimize)

# %%
for idx in m1.X_index:
    m1.x[idx].value = start_x[idx]


solver2 = pyo.SolverFactory("gurobi")
solver2.options["TimeLimit"] = 200
solver2.options["MIPFocus"] = 1
#solver2.options["Heuristics"] = 0.4
#solver2.options["NoRelHeurTime"] = 50
#solver2.options["RINS"] = 20



# warmstart=True is important
res2 = solver2.solve(m1, tee=True, warmstart=True)

tc2 = res2.solver.termination_condition
print("Phase 2 termination:", tc2)
print("Phase 2 objective:", pyo.value(m1.obj))
# Out:
# Read LP format model from file C:\Users\asher\AppData\Local\Temp\tmpck9_laan.pyomo.lp
# Reading time = 1.42 seconds
# x1: 19009 rows, 270035 columns, 1839725 nonzeros
# Read MIP start from file C:\Users\asher\AppData\Local\Temp\tmpr09kmc6h.gurobi.mst
# Set parameter TimeLimit to value 200
# Set parameter MIPFocus to value 1
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: Intel(R) Core(TM) i5-10210U CPU @ 1.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  200
# MIPFocus  1
#
# Optimize a model with 19009 rows, 270035 columns and 1839725 nonzeros (Min)
# Model fingerprint: 0x5f1dea0c
# Model has 109458 linear objective coefficients
# Variable types: 2660 continuous, 267375 integer (267375 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
#
# User MIP start produced solution with objective 10609 (0.34s)
# Loaded user MIP start with objective 10609
#
# Presolve removed 3144 rows and 1091 columns
# Presolve time: 4.15s
# Presolved: 15865 rows, 268944 columns, 1563036 nonzeros
# Variable types: 146 continuous, 268798 integer (267554 binary)
# Deterministic concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Root barrier log...
#
# Ordering time: 0.11s
#
# Barrier statistics:
#  AA' NZ     : 1.683e+05
#  Factor NZ  : 3.975e+05 (roughly 20 MB of memory)
#  Factor Ops : 1.609e+07 (less than 1 second per iteration)
#  Threads    : 2
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   7.01963006e+06 -7.13564221e+05  4.19e+03 0.00e+00  4.25e+02     7s
#    1   5.34518971e+06 -4.94366797e+05  3.20e+03 1.77e+01  3.28e+02     7s
#    2   3.32815973e+05 -2.32559369e+05  2.05e+02 1.72e-01  2.31e+01     7s
#    3   5.94969606e+04 -9.46077137e+04  3.11e+01 1.99e-13  4.20e+00     7s
#    4   2.10628782e+04 -8.19672451e+04  9.59e+00 1.71e-13  1.93e+00     8s
#
# Barrier performed 4 iterations in 7.55 seconds (4.79 work units)
# Barrier solve interrupted - model solved by another algorithm
#
# Concurrent spin time: 0.01s
#
# Solved with dual simplex
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     4390    4.0000000e+00   0.000000e+00   0.000000e+00      8s
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 8s
#
#    28617 PPushes remaining with PInf 0.0000000e+00                 8s
#        0 PPushes remaining with PInf 0.0000000e+00                 8s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      8s
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    33011    4.0000000e+00   0.000000e+00   0.000000e+00      8s
# Crossover time: 0.38 seconds (0.09 work units)
#
# Root relaxation: objective 4.000000e+00, 33011 iterations, 2.34 seconds (0.89 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                       4.0000000    4.00000  0.00%     -    8s
#      0     0    4.00000    0  179    4.00000    4.00000  0.00%     -    8s
#
# Explored 1 nodes (33011 simplex iterations) in 8.51 seconds (4.87 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 4 10609
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.000000000000e+00, best bound 4.000000000000e+00, gap 0.0000%
# Phase 2 termination: optimal
# Phase 2 objective: 4.0

# %%
for idx in m1.X_index:
    m1.x[idx].value = start_x[idx]


solver2 = pyo.SolverFactory("gurobi")
solver2.options["TimeLimit"] = 100
solver2.options["MIPFocus"] = 1
solver2.options["Heuristics"] = 0.4
solver2.options["NoRelHeurTime"] = 50
solver2.options["RINS"] = 20



# warmstart=True is important
res2 = solver2.solve(m1, tee=True, warmstart=True)

tc2 = res2.solver.termination_condition
print("Phase 2 termination:", tc2)
print("Phase 2 objective:", pyo.value(m1.obj))
# Out:
# Read LP format model from file C:\Users\asher\AppData\Local\Temp\tmpe03e1g1u.pyomo.lp
# Reading time = 1.49 seconds
# x1: 19009 rows, 270035 columns, 1839725 nonzeros
# Read MIP start from file C:\Users\asher\AppData\Local\Temp\tmpc8gvepwl.gurobi.mst
# Set parameter TimeLimit to value 100
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.4
# Set parameter NoRelHeurTime to value 50
# Set parameter RINS to value 20
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: Intel(R) Core(TM) i5-10210U CPU @ 1.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  100
# Heuristics  0.4
# MIPFocus  1
# NoRelHeurTime  50
# RINS  20
#
# Optimize a model with 19009 rows, 270035 columns and 1839725 nonzeros (Min)
# Model fingerprint: 0x5f1dea0c
# Model has 109458 linear objective coefficients
# Variable types: 2660 continuous, 267375 integer (267375 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
#
# User MIP start produced solution with objective 10609 (0.33s)
# Loaded user MIP start with objective 10609
#
# Presolve removed 3144 rows and 1091 columns
# Presolve time: 4.08s
# Presolved: 15865 rows, 268944 columns, 1563036 nonzeros
# Variable types: 146 continuous, 268798 integer (267554 binary)
# Starting NoRel heuristic
# Found heuristic solution: objective 2933.0000000
# Found heuristic solution: objective 1983.0000000
# Found heuristic solution: objective 1971.0000000
# Found heuristic solution: objective 1709.0000000
# Found heuristic solution: objective 1523.0000000
# Found heuristic solution: objective 1493.0000000
# Found heuristic solution: objective 1238.0000000
# Found heuristic solution: objective 848.0000000
# Found heuristic solution: objective 634.0000000
# Found heuristic solution: objective 582.0000000
# Found heuristic solution: objective 390.0000000
# Found heuristic solution: objective 356.0000000
# Elapsed time for NoRel heuristic: 6s (best bound 2)
# Found heuristic solution: objective 229.0000000
# Found heuristic solution: objective 147.0000000
# Found heuristic solution: objective 140.0000000
# Found heuristic solution: objective 113.0000000
# Found heuristic solution: objective 102.0000000
# Found heuristic solution: objective 75.0000000
# Found heuristic solution: objective 61.0000000
# Elapsed time for NoRel heuristic: 13s (best bound 2)
# Found heuristic solution: objective 34.0000000
# Found heuristic solution: objective 32.0000000
# Elapsed time for NoRel heuristic: 19s (best bound 2)
# Found heuristic solution: objective 28.0000000
# Found heuristic solution: objective 20.0000000
# Found heuristic solution: objective 10.0000000
# Elapsed time for NoRel heuristic: 26s (best bound 2)
# Found heuristic solution: objective 8.0000000
# Found heuristic solution: objective 5.0000000
# Elapsed time for NoRel heuristic: 33s (best bound 2)
# Elapsed time for NoRel heuristic: 54s (best bound 4)
# NoRel heuristic complete
# Deterministic concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Root barrier log...
#
# Ordering time: 0.05s
#
# Barrier statistics:
#  AA' NZ     : 1.361e+05
#  Factor NZ  : 2.613e+05 (roughly 15 MB of memory)
#  Factor Ops : 9.203e+06 (less than 1 second per iteration)
#  Threads    : 2
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   8.22795215e+04 -3.87148067e+03  4.24e+03 0.00e+00  3.36e+01    60s
#    1   2.02021984e+04 -1.11091075e+04  9.68e+02 2.89e-01  7.78e+00    60s
#    2   1.19267848e+03 -9.62214103e+03  2.00e+01 1.63e-03  3.35e-01    60s
#
# Barrier performed 2 iterations in 59.64 seconds (17.22 work units)
# Barrier solve interrupted - model solved by another algorithm
#
# Concurrent spin time: 0.00s
#
# Solved with dual simplex
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     5109    4.0000000e+00   0.000000e+00   0.000000e+00     60s
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root crossover log...
#
#    28997 PPushes remaining with PInf 0.0000000e+00                60s
#        0 PPushes remaining with PInf 0.0000000e+00                60s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00     60s
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    34109    4.0000000e+00   0.000000e+00   0.000000e+00     60s
# Crossover time: 0.30 seconds (0.08 work units)
#    34109    4.0000000e+00   0.000000e+00   0.000000e+00     60s
#
# Root relaxation: objective 4.000000e+00, 34109 iterations, 1.38 seconds (0.83 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                       4.0000000    4.00000  0.00%     -   60s
#      0     0    4.00000    0  246    4.00000    4.00000  0.00%     -   60s
#
# Explored 1 nodes (34109 simplex iterations) in 60.19 seconds (17.33 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 4 5 8 ... 75
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.000000000000e+00, best bound 4.000000000000e+00, gap 0.0000%
# Phase 2 termination: optimal
# Phase 2 objective: 4.0

# %%
# Build chosen_start from m1 solution
chosen_start = {}
for se in m1.SE:
    picked = [ts for ts in feasible_starts[se] if pyo.value(m1.x[se, ts]) > 0.5]
    if len(picked) != 1:
        raise ValueError(f"Event {se}: expected exactly 1 chosen start, got {picked}")
    chosen_start[se] = picked[0]

print("Assigned starts:", len(chosen_start), "out of", len(list(m1.SE)))
#chosen_start
# Out:
# Assigned starts: 2849 out of 2849

# %% [markdown]
# ### 2d: Model 3

# %%
# ---- Model ----
m2 = pyo.ConcreteModel()

# ---- Sets ----
m2.E = pyo.Set(initialize=E) # Set of events
m2.T = pyo.Set(initialize=T, ordered=True) # Set of timeslots (ordered)
m2.R = pyo.Set(initialize=R) # Set of rooms

m2.SE = pyo.Set(initialize=SE) # Set of rooms


# standard set up
m2.X_index = pyo.Set(
    dimen=2,
    initialize=[(se, r) for se in SE for r in R]
)



events_occupying_t = defaultdict(list)
for se in SE:
    ts = chosen_start[se]
    for t in occ_times[(se, ts)]:
        events_occupying_t[t].append(se)

# ---- Decision Variables ----
# Start-time decision variables:
# x[e, ts, r] = 1 if event e starts at time ts in room r
# Only define variables for feasible starts (and all rooms) (THIS SPEEDS UP MODEL)
m2.x = pyo.Var(m2.X_index, domain=pyo.Binary)

# %%
# Standard set up

# 1) Each event gets exactly one room
def one_room_rule(m, e):
    return sum(m.x[e, r] for r in R) == 1
m2.OneRoom = pyo.Constraint(m2.SE, rule=one_room_rule)


# 2) No room conflicts: at most one event can occupy a room at a time
def room_conflict_rule(m, r, t):
    terms = [m.x[e, r] for e in events_occupying_t.get(t, []) if (e, r) in m.X_index]
    if not terms:
        return pyo.Constraint.Skip
    return sum(terms) <= 1

m2.RoomConflict = pyo.Constraint(m2.R, m2.T, rule=room_conflict_rule)

# %%
# 1) keep prefer-resource constraints
cdf = df_constraints[df_constraints["constraint_type"] == "PreferResourcesConstraint"].copy()
cdf = cdf[cdf["required"].astype(str).str.upper() != "TRUE"]
cdf = cdf[~cdf["name"].astype(str).str.startswith("PreferResourceConstraint_Dept")]

cids = set(cdf["constraint_id"])
cid_to_weight = cdf.set_index("constraint_id")["weight"].astype(float).to_dict()

# 2) role per constraint (we only enforce Room-role constraints)
role_rows = df_constraint_params[
    (df_constraint_params["constraint_id"].isin(cids)) &
    (df_constraint_params["path"] == "Role")
][["constraint_id", "value"]]
cid_to_role = role_rows.set_index("constraint_id")["value"].to_dict()

# 3) preferred resources per constraint: direct resources
pref_resources = {cid: set() for cid in cids}

direct_res = df_constraint_params[
    (df_constraint_params["constraint_id"].isin(cids)) &
    (df_constraint_params["path"] == "Resources/Resource")
][["constraint_id", "value"]]
for r in direct_res.itertuples(index=False):
    pref_resources[r.constraint_id].add(r.value)

# %%
# 4) preferred resources via resource groups
rg_rows = df_constraint_params[
    (df_constraint_params["constraint_id"].isin(cids)) &
    (df_constraint_params["path"] == "ResourceGroups/ResourceGroup")
][["constraint_id", "value"]]

# map roomgroup -> resources
rg_to_resources = (
    resource_groups.groupby("resource_group_id")["resource_id"].apply(set).to_dict()
)

for r in rg_rows.itertuples(index=False):
    pref_resources[r.constraint_id].update(rg_to_resources.get(r.value, set()))

# 5) applies-to events: direct + via event groups

# map constraint -> event applied to (one at a time)
applied_event = (
    df_constraint_applied[
        (df_constraint_applied["constraint_id"].isin(cids)) &
        (df_constraint_applied["path"] == "AppliesTo/Events/Event")
    ][["constraint_id", "reference"]]
    .groupby("constraint_id")["reference"].apply(set).to_dict()
)

# map eventgroup -> event 
applies_eg = df_constraint_applied[
    (df_constraint_applied["constraint_id"].isin(cids)) &
    (df_constraint_applied["path"] == "AppliesTo/EventGroups/EventGroup")
][["constraint_id", "reference"]]

eg_to_events = (
    df_event_groups_membership.groupby("event_group_id")["event_id"].apply(set).to_dict()
)

# map constraint -> event applied to (lists)
applied_events = {cid: set(applied_event.get(cid, set())) for cid in cids}
for r in applies_eg.itertuples(index=False):
    applied_events[r.constraint_id].update(eg_to_events.get(r.reference, set()))

# %%
# 6) parent -> sub-events, sub-event -> duration
parent_to_sub = df_sub_events.groupby("parent_event_id")["sub_event_id"].apply(list).to_dict()
sub_duration = df_sub_events.set_index("sub_event_id")["sub_duration"].astype(int).to_dict()

all_rooms = set(df_rooms["resource_id"].tolist())

# 7) penalty expression
penalty = 0.0

for cid in cids: # for each constraint
    # only room-role prefer constraints in this function
    w = 1 # constraint weight
    pref = pref_resources.get(cid, set()) # constraint preferred resources
    nonpref = all_rooms - pref # constraint not preferred resources
    
    for pe in applied_events.get(cid, set()): # for each event in constraint
        for se in parent_to_sub.get(pe, []): # for each sub event in event
            d = int(sub_duration[se]) # duration of sub event
            # deviation contribution: duration if assigned to non-preferred room
            penalty += w * d * sum(m2.x[se, r] for r in nonpref)


m2.PreferRoomPenalty = pyo.Expression(expr=penalty)

# %%
# 4) PreferResourcesConstraint_Dept
# Selected event prefers rooms from selected room-group(s)
# Soft, linear, weight = 1

# --- keep only dept prefer-resource constraints ---
cdf_dept = df_constraints[df_constraints["constraint_type"] == "PreferResourcesConstraint"].copy()
cdf_dept = cdf_dept[cdf_dept["required"].astype(str).str.upper() != "TRUE"]
cdf_dept = cdf_dept[cdf_dept["name"].astype(str).str.startswith("PreferResourceConstraint_Dept_")]

dept_cids = set(cdf_dept["constraint_id"])

# --- role map (optional safety) ---
role_rows = df_constraint_params[
    (df_constraint_params["constraint_id"].isin(dept_cids)) &
    (df_constraint_params["path"] == "Role")
][["constraint_id", "value"]]
cid_to_role = role_rows.set_index("constraint_id")["value"].to_dict()

# --- preferred resources per dept-constraint ---
pref_resources_dept = {cid: set() for cid in dept_cids}

# df constraint id and room group
rg_rows = df_constraint_params[
    (df_constraint_params["constraint_id"].isin(dept_cids)) &
    (df_constraint_params["path"] == "ResourceGroups/ResourceGroup")
][["constraint_id", "value"]]

# map resource group -> resource
rg_to_resources = (
    resource_groups.groupby("resource_group_id")["resource_id"].apply(set).to_dict()
)


for r in rg_rows.itertuples(index=False):
    pref_resources_dept[r.constraint_id].update(rg_to_resources.get(r.value, set()))

# --- applies-to events (direct + via event groups) ---

# map constraint -> event
applied_event = (
    df_constraint_applied[
        (df_constraint_applied["constraint_id"].isin(dept_cids)) &
        (df_constraint_applied["path"] == "AppliesTo/Events/Event")
    ][["constraint_id", "reference"]]
    .groupby("constraint_id")["reference"].apply(set).to_dict()
)

applies_eg = df_constraint_applied[
    (df_constraint_applied["constraint_id"].isin(dept_cids)) &
    (df_constraint_applied["path"] == "AppliesTo/EventGroups/EventGroup")
][["constraint_id", "reference"]]

# map event group -> events
eg_to_events = (
    df_event_groups_membership.groupby("event_group_id")["event_id"].apply(set).to_dict()
)

# map 
applied_events = {cid: set(applied_event.get(cid, set())) for cid in dept_cids}
for r in applies_eg.itertuples(index=False):
    applied_events[r.constraint_id].update(eg_to_events.get(r.reference, set()))

# --- parent -> sub-events / sub-event duration ---
parent_to_sub = df_sub_events.groupby("parent_event_id")["sub_event_id"].apply(list).to_dict()
sub_duration = df_sub_events.set_index("sub_event_id")["sub_duration"].astype(int).to_dict()

all_rooms = set(df_rooms["resource_id"].tolist())

# --- penalty expression ---
dept_penalty = 0.0

for cid in dept_cids: # for each constraint
    w = 1.0 # constraint weight
    pref = pref_resources_dept.get(cid, set()) # constraint preferred resources
    nonpref = all_rooms - pref # constraint not preferred rooms

    for pe in applied_events.get(cid, set()): # for event in constraint group
        for se in parent_to_sub.get(pe, []): # for sub event in event
            d = int(sub_duration[se]) # sub event duration
            dept_penalty += w * d * sum(m2.x[se, r] for r in nonpref)

m2.PreferDeptPenalty = pyo.Expression(expr=dept_penalty)

# %% [markdown]
# ### Solve

# %%
# ---- Objective ---- (with soft constraints)
penalty_total = (m2.PreferRoomPenalty + m2.PreferDeptPenalty)

m2.obj = pyo.Objective(expr=penalty_total, sense=pyo.minimize)

# %%
solver2 = pyo.SolverFactory("gurobi")
solver2.options["TimeLimit"] = 200
solver2.options["MIPFocus"] = 1
solver2.options["Heuristics"] = 0.4
solver2.options["NoRelHeurTime"] = 50
solver2.options["RINS"] = 20

# warmstart=True is important
res2 = solver2.solve(m2, tee=True)

tc2 = res2.solver.termination_condition
print("Phase 2 termination:", tc2)
print("Phase 2 objective:", pyo.value(m2.obj))
# Out:
# Read LP format model from file C:\Users\asher\AppData\Local\Temp\tmp7ez_532v.pyomo.lp
# Reading time = 1.22 seconds
# x1: 13649 rows, 307692 columns, 993924 nonzeros
# Set parameter TimeLimit to value 200
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.4
# Set parameter NoRelHeurTime to value 50
# Set parameter RINS to value 20
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: Intel(R) Core(TM) i5-10210U CPU @ 1.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  200
# Heuristics  0.4
# MIPFocus  1
# NoRelHeurTime  50
# RINS  20
#
# Optimize a model with 13649 rows, 307692 columns and 993924 nonzeros (Min)
# Model fingerprint: 0x93cec601
# Model has 280340 linear objective coefficients
# Variable types: 0 continuous, 307692 integer (307692 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 5778.0000000
# Presolve removed 11404 rows and 228528 columns
# Presolve time: 4.53s
# Presolved: 2245 rows, 79164 columns, 204984 nonzeros
# Found heuristic solution: objective 1894.0000000
# Variable types: 0 continuous, 79164 integer (79164 binary)
# Starting NoRel heuristic
# Found heuristic solution: objective 1318.0000000
# Found heuristic solution: objective 1019.0000000
# Found heuristic solution: objective 832.0000000
# Found heuristic solution: objective 800.0000000
# Found heuristic solution: objective 766.0000000
# Found heuristic solution: objective 721.0000000
# Found heuristic solution: objective 715.0000000
# Found heuristic solution: objective 711.0000000
# Found heuristic solution: objective 687.0000000
# Found heuristic solution: objective 673.0000000
# Found heuristic solution: objective 643.0000000
# Found heuristic solution: objective 629.0000000
# Found heuristic solution: objective 627.0000000
# Found heuristic solution: objective 615.0000000
# Found heuristic solution: objective 611.0000000
# Found heuristic solution: objective 567.0000000
# NoRel heuristic complete
#
# Explored 0 nodes (0 simplex iterations) in 6.68 seconds (3.46 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 567 611 615 ... 715
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.670000000000e+02, best bound 5.670000000000e+02, gap 0.0000%
# Phase 2 termination: optimal
# Phase 2 objective: 4.0

# %%
solver2 = pyo.SolverFactory("gurobi")
solver2.options["TimeLimit"] = 200
solver2.options["MIPFocus"] = 1
#solver2.options["Heuristics"] = 0.4
#solver2.options["NoRelHeurTime"] = 50
#solver2.options["RINS"] = 20

# warmstart=True is important
res2 = solver2.solve(m2, tee=True)

tc2 = res2.solver.termination_condition
print("Phase 2 termination:", tc2)
print("Phase 2 objective:", pyo.value(m2.obj))
# Out:
# Read LP format model from file C:\Users\asher\AppData\Local\Temp\tmpigegyqux.pyomo.lp
# Reading time = 1.11 seconds
# x1: 13649 rows, 307692 columns, 993924 nonzeros
# Set parameter TimeLimit to value 200
# Set parameter MIPFocus to value 1
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: Intel(R) Core(TM) i5-10210U CPU @ 1.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  200
# MIPFocus  1
#
# Optimize a model with 13649 rows, 307692 columns and 993924 nonzeros (Min)
# Model fingerprint: 0x93cec601
# Model has 280340 linear objective coefficients
# Variable types: 0 continuous, 307692 integer (307692 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 5778.0000000
# Presolve removed 11404 rows and 228528 columns
# Presolve time: 4.52s
# Presolved: 2245 rows, 79164 columns, 204984 nonzeros
# Found heuristic solution: objective 1894.0000000
# Variable types: 0 continuous, 79164 integer (79164 binary)
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing primal log only...
#
# Concurrent spin time: 0.00s
#
# Solved with dual simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover time: 0.06 seconds (0.03 work units)
#
# Root relaxation: objective 5.670000e+02, 8174 iterations, 0.21 seconds (0.12 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                     567.0000000  567.00000  0.00%     -    4s
#      0     0  567.00000    0  692  567.00000  567.00000  0.00%     -    4s
#
# Explored 1 nodes (8174 simplex iterations) in 4.97 seconds (2.93 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 567 1894 5778
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.670000000000e+02, best bound 5.670000000000e+02, gap 0.0000%
# Phase 2 termination: optimal
# Phase 2 objective: 567.0

# %%
# ---- Objective ---- 
m2.obj = pyo.Objective(expr=0, sense=pyo.minimize)

# %%
# ---- Solve ---

solver = pyo.SolverFactory("gurobi")
# solver.options["TimeLimit"] = 1000
# solver.options["MIPGap"] = 0.0

res = solver.solve(m2, tee=True)

print(res.solver.termination_condition)
# Out:
# Read LP format model from file C:\Users\asher\AppData\Local\Temp\tmpbrm9vimo.pyomo.lp
# Reading time = 1.05 seconds
# x1: 13649 rows, 307693 columns, 993924 nonzeros
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: Intel(R) Core(TM) i5-10210U CPU @ 1.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 13649 rows, 307693 columns and 993924 nonzeros (Min)
# Model fingerprint: 0x11d7e3d3
# Model has 0 linear objective coefficients
# Variable types: 1 continuous, 307692 integer (307692 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 0.0000000
#
# Explored 0 nodes (0 simplex iterations) in 0.12 seconds (0.03 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 1: 0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 0.000000000000e+00, best bound 0.000000000000e+00, gap 0.0000%
# optimal

# %%
chosen_rows = []
for se in m2.SE:
    chosen_room = None
    for r in m2.R:
        v = pyo.value(m2.x[se, r], exception=False)
        if v is not None and v > 0.5:
            chosen_room = r
            break
    chosen_rows.append({"sub_event_id": se, "chosen_room": chosen_room})

df_chosen_rooms = pd.DataFrame(chosen_rows)

# build map: sub_event_id -> chosen_room
warm_map = dict(zip(df_chosen_rooms["sub_event_id"], df_chosen_rooms["chosen_room"]))


# optional checks
print("Unassigned sub-events:", df_chosen_rooms["chosen_room"].isna().sum())
display(df_chosen_rooms.head())
# Out:
# Unassigned sub-events: 0
#                        sub_event_id chosen_room
# 0  Accounting-Advanced(H)_0_1__sub1      Room_5
# 1  Accounting-Advanced(H)_0_1__sub2     Room_15
# 2  Accounting-Advanced(H)_0_1__sub3     Room_69
# 3  Accounting-Advanced(H)_0_1__sub4      Room_8
# 4     Accounting-Begining_0_1__sub1      Room_2

# %%
# ---- Objective ---- (with soft constraints)

if hasattr(m2, "obj"):
    m2.del_component(m2.obj)

penalty_total = (m2.PreferRoomPenalty + m2.PreferDeptPenalty)

m2.obj = pyo.Objective(expr=penalty_total, sense=pyo.minimize)

# %%
# set start values on m2.x[(se, r)]
for (se, r) in m2.X_index:
    m2.x[se, r].value = 1 if warm_map.get(se) == r else 0

solver2 = pyo.SolverFactory("gurobi")
solver2.options["TimeLimit"] = 100
#solver2.options["MIPFocus"] = 1
#solver2.options["Heuristics"] = 0.4
#solver2.options["NoRelHeurTime"] = 50
#solver2.options["RINS"] = 20


# warmstart=True is important
res2 = solver2.solve(m2, tee=True, warmstart=True)  

tc2 = res2.solver.termination_condition
print("Phase 2 termination:", tc2)
print("Phase 2 objective:", pyo.value(m2.obj))
# Out:
# Read LP format model from file C:\Users\asher\AppData\Local\Temp\tmp5uyvfw9s.pyomo.lp
# Reading time = 1.12 seconds
# x1: 13649 rows, 307692 columns, 993924 nonzeros
# Read MIP start from file C:\Users\asher\AppData\Local\Temp\tmpsc1zrtci.gurobi.mst
# Set parameter TimeLimit to value 100
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: Intel(R) Core(TM) i5-10210U CPU @ 1.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  100
#
# Optimize a model with 13649 rows, 307692 columns and 993924 nonzeros (Min)
# Model fingerprint: 0xebbc327a
# Model has 280340 linear objective coefficients
# Variable types: 0 continuous, 307692 integer (307692 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# Loaded user MIP start with objective 5807
#
# Presolve removed 11404 rows and 228528 columns
# Presolve time: 4.19s
# Presolved: 2245 rows, 79164 columns, 204984 nonzeros
# Found heuristic solution: objective 1886.0000000
# Variable types: 0 continuous, 79164 integer (79164 binary)
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing primal log only...
#
# Concurrent spin time: 0.00s
#
# Solved with dual simplex
#
# Use crossover to convert LP symmetric solution to basic solution...
# Crossover time: 0.05 seconds (0.03 work units)
#
# Root relaxation: objective 5.670000e+02, 8174 iterations, 0.20 seconds (0.12 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                     567.0000000  567.00000  0.00%     -    4s
#      0     0  567.00000    0  692  567.00000  567.00000  0.00%     -    4s
#
# Explored 1 nodes (8174 simplex iterations) in 4.57 seconds (2.91 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 567 1886 5807
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.670000000000e+02, best bound 5.670000000000e+02, gap 0.0000%
# Phase 2 termination: optimal
# Phase 2 objective: 567.0

# %%
# set start values on m2.x[(se, r)]
for (se, r) in m2.X_index:
    m2.x[se, r].value = 1 if warm_map.get(se) == r else 0

solver2 = pyo.SolverFactory("gurobi")
solver2.options["TimeLimit"] = 100
solver2.options["MIPFocus"] = 1
solver2.options["Heuristics"] = 0.4
solver2.options["NoRelHeurTime"] = 50
solver2.options["RINS"] = 20


# warmstart=True is important
res2 = solver2.solve(m2, tee=True, warmstart=True)  

tc2 = res2.solver.termination_condition
print("Phase 2 termination:", tc2)
print("Phase 2 objective:", pyo.value(m2.obj))
# Out:
# Read LP format model from file C:\Users\asher\AppData\Local\Temp\tmprg1tuwmu.pyomo.lp
# Reading time = 1.13 seconds
# x1: 13649 rows, 307692 columns, 993924 nonzeros
# Read MIP start from file C:\Users\asher\AppData\Local\Temp\tmpbuzwjocf.gurobi.mst
# Set parameter TimeLimit to value 100
# Set parameter MIPFocus to value 1
# Set parameter Heuristics to value 0.4
# Set parameter NoRelHeurTime to value 50
# Set parameter RINS to value 20
# Gurobi Optimizer version 13.0.0 build v13.0.0rc1 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: Intel(R) Core(TM) i5-10210U CPU @ 1.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  100
# Heuristics  0.4
# MIPFocus  1
# NoRelHeurTime  50
# RINS  20
#
# Optimize a model with 13649 rows, 307692 columns and 993924 nonzeros (Min)
# Model fingerprint: 0xefe9c0a6
# Model has 280340 linear objective coefficients
# Variable types: 0 continuous, 307692 integer (307692 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 4e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# Loaded user MIP start with objective 5802
#
# Presolve removed 11199 rows and 229716 columns
# Presolve time: 4.58s
# Presolved: 2450 rows, 77976 columns, 214056 nonzeros
# Found heuristic solution: objective 1879.0000000
# Variable types: 0 continuous, 77976 integer (77976 binary)
# Starting NoRel heuristic
# Found heuristic solution: objective 1241.0000000
# Found heuristic solution: objective 931.0000000
# Found heuristic solution: objective 908.0000000
# Found heuristic solution: objective 906.0000000
# Found heuristic solution: objective 894.0000000
# Found heuristic solution: objective 796.0000000
# Found heuristic solution: objective 766.0000000
# Found heuristic solution: objective 719.0000000
# Found heuristic solution: objective 681.0000000
# Found heuristic solution: objective 657.0000000
# Found heuristic solution: objective 647.0000000
# Found heuristic solution: objective 639.0000000
# Found heuristic solution: objective 635.0000000
# Found heuristic solution: objective 625.0000000
# Found heuristic solution: objective 623.0000000
# Found heuristic solution: objective 601.0000000
# Found heuristic solution: objective 600.0000000
# Found heuristic solution: objective 595.0000000
# Found heuristic solution: objective 539.0000000
# NoRel heuristic complete
#
# Explored 0 nodes (0 simplex iterations) in 6.59 seconds (3.31 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 539 595 600 ... 657
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.390000000000e+02, best bound 5.390000000000e+02, gap 0.0000%
# Phase 2 termination: optimal
# Phase 2 objective: 539.0
